# %% [markdown]
# <font color='blue'><font size="6.9"> The Examples for the Utilization of the 'CosmPSPy' Code
#
#
# <font color='green'><font size="4">Dr. Fei QIN\
# CPPM, CNRS/IN2P3, Aix-Marseille University, Marseille, France. 2025 July. \
# E-mail:  qin@cppm.in2p3.fr
# </font></font>\
# (Any bug of the code can be reported to the above email address)
#
#
#
#
# To install the PYTHON package 'CosmPSPy', the users can simply download the '<font color='brown'>PSestFun.py</font>' and '<font color='brown'>PSmodFun.py</font>' to their laptop, then importing them using: \
# <font color='green'> from PSestFun import * </font>\
# <font color='green'> from PSmodFun import * </font>\
# So easy !!!      The <font color='brown'>PSestFun.py</font> is used to measure the power spectrum, while the <font color='brown'>PSmodFun.py</font> is used to model the power spectrum and calculate the window function convolution. The code can be downloaded from the GitHub link:   https://github.com/FeiQin-cosmologist/Galaxy_Power_Spectrum  . The following Python packages are required to be installed for our code:\
# 1: numpy\
# 2: scipy
#
# The users will need to <font size="4"><font color='red'>cite</font></font> the following papers when using our code:\
# Paper I&nbsp;&nbsp;: Howlett 2019&nbsp;&nbsp;&nbsp;&nbsp;: https://arxiv.org/abs/1906.02875 \
# Paper II&nbsp;: Qin et al. 2019b: https://arxiv.org/abs/1906.02874 \
# Paper III: Qin et al. 2024&nbsp;&nbsp;: https://arxiv.org/abs/2411.09571 . \
# Paper IV: Qin et al. 2026&nbsp;&nbsp;:
#
#
# \
# <font color='brown'><font size="4.9"> Contents </font>
#
# <font color='brown'>Part 1. The Introduction of the Redshift-Space Galaxy Power Spectrum</font>
#
# <font color='brown'>Part 2. The Measurements of the Redshift-Space Galaxy Power Spectrum</font> \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 2.1 Measuring Power Spectrum of Galaxy Survey \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.1.1 The Density Power Spectrum  \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.1.2 The Momentum Power Spectrum\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.1.3 The Cross Power Spectrum
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 2.2 Measuring Power Spectrum of Randoms
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2.2.1 Some Important Outputs\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 2.3 Measuring Power Spectrum of Periodic Simulation Box
#
#
# <font color='brown'>Part 3. The Window Function Covolution</font>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 3.1 Ross Method\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 3.2 CosmPS Method\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 3.3 Pypower Method
#
#
# <font color='brown'>Part 4. The Theoretical Models of the Redshift-Space Galaxy Power Spectrum</font> \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 4.1 Introduction \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 4.2 The Parameters of the Models \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.2.1 The Parameters \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.2.2 Some Suggestions About the Choice of the Free Parameters \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 4.3 Calculating the Redshift-Space Power Spectrum Model $P(k,\mu)$ \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.3.1 The Redshift-Space Power Spectrum Model $P(k,\mu)$  \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.3.2 Convert the 2D Power Spectrum $P(k,\mu)$ to 1D Power Spectrum $P(k)$ \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 4.4 Calculating the Power Spectrum Multipole Model $P_{\ell}(k )$ \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 4.5 Calculating the Window Function Convolved Power Spectrum Multipole Model $P^c_{\ell}(k )$ \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 4.6 Comparing the Perturbation Models to Kaiser Formulars
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.6.1 Comparing 2D Power Spectrum $P(k, \mu)$ \
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.6.2 Comparing Power Spectrum Multipoles\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4.6.3 Window Function Convolution of Kaiser Formular\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 4.7 Calculate Fiducial Growth Rate at Effective Redshift
#
#
# <font color='brown'>Part 5. The Theoretical Models of the Galaxy Two-Point Correlation Function</font>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 5.1 Galaxy Correlation Function\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 5.2 Velocity Correlation Function\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Section 5.3 Galaxy-Velocity Cross Correlation Function
#
# \
#     \
#     \
# <font color='brown'><font size="5.9">Part 1. The Introduction of the Redshift-Space Galaxy Power Spectrum</font></font>
#
# The large-scale structure of the Universe and its evolution over time contains an abundance of cosmological information.
# One way to unlock this is by measuring the density, momentum and cross power spectrum from the positions and peculiar velocities of galaxies, and fitting  the cosmological parameters from these power spectrum. The cosmological parameters that we seek to measure are the growth rate of
# structure $$f\equiv  \frac{d\ln\,D(a)}{d\ln\,a}$$ which is the derivative of the linear growth factor $D(a)$ with respect to the  scale factor $a$, and the galaxy bias parameter $$b\equiv  \sqrt{\frac{ P_{g}({\bf k})}{P_{\mathrm{DM}}({\bf k})}}$$ which is the ratio between the galaxies density and dark matter density, where $P_{\mathrm{DM}}$ and $P_{g}$ are the dark matter and galaxies density power spectrum, respectively. Moreover,  the growth rate and galaxy bias parameter can be  normalized as $f\sigma_8$ and $b\sigma_8$, where $\sigma_8$ is defined as  the root mean square of the mass density fluctuation within spheres of 8 Mpc $h^{-1}$. Both $f\sigma_8$ and $b\sigma_8$ are measurable from galaxies.
#
#
# The Hubble recessional redshift and peculiar velocity of a galaxy contribute to form its observed redshift. Therefore, the position of a galaxy inferred from its observed redshift is not its true comoving position (real-space possition). Instead, it is a ‘redshift-space’ position contaminated by the peculiar motion. This is the so-called redshift-space distortion (RSD). The spherical symmetry about the line of sight of the power spectrum estimated from the galaxies’ redshift-space positions is broken by RSD. Therefore, a common method is to decompose the redshift-space power spectrum $P(k,\mu)$ using the Legendre polynomials $𝐿_{\ell}(\mu)$, i.e.
# $$P(k, \mu)= \sum_{\ell}P_{\ell}(k )L_{\ell}(\mu)$$
# where $\ell=0,1,2,3,4,...$. The $k$ is the wave number. The cosine of the angle between the     unit wave vector ${\bf\hat{k}}$ and the line-of-sight unit position vector ${\bf\hat{r}}$ is $\mu={\bf\hat{r}}\cdot {\bf\hat{k}}=\mathrm{cos}\,\theta$.
# The $P_{\ell}(k )$ is the so-called power spectrum multipoles, which is computed from the Legendre transformation of the
# redshift-space power pectrum $P(k,\mu)$, i.e.
# $$P_l(k)=\frac{(2\ell+1)}{2} \int^1_{-1}P(k,\mu)L_l(\mu)d\mu$$
# The power spectrum multipoles can be measured from galaxy surveys. By comparing the measured power spectrum multipoles to the theoritical models of power spectrum multipoles, we can estimate the growth rate and bias parameter of the large-scale-structure.
#
#
# In this notebook, we will explore the galaxy redshift-space auto-density power spectrum $P^{\delta}(k)$, auto-momentum power spectrum $P^{p}(k)$ and the density-momentum-cross power spectrum $P^{\delta p}(k)$. In the absence of wide-angle or general relativistic effects, only the even-multipoles of the auto-power spectrum are non-zero. Under similar conditions, only the odd-multipoles of the cross power spectrum are non-zero.
#
# \
# \
# <font color='brown'><font size="5.9">Part 2. The Measurements of the Redshift-Space Galaxy Power Spectrum</font></font>
#
# We need the galaxy and random catalogues in order to measure the power spectrum. The random catalogue will be used to measure the density and cross power spectrum. We do not need random catalogue to measure the momentum power spectrum.  To measure the density power spectrum, we need: \
# ra, raR  : the Right Ascension of galaxies and randoms, respectively; \
# dec, decR: the Declination of galaxies and randoms, respectively; \
# zm, zmR  : the observed redshift of galaxies and randoms, respectively.\
# In addition to the above, we need the following infomation to measure the momentum and cross power spectrum:
# vp       : the peculiar velocities of galaxies.  \
# evp      : the errors of the peculiar velocities.
#
# The survey sky coverage area of our example data catalogue is $4\pi\times 0.413159$. The module we have used to measure power spectrum is <font color='brown'>PSestFun.py</font>, to load the module, please run ' <font color='green'> from PSestFun import * </font>'.
#
# Call the following function to measure power spectrum:
# <font color='green'><font size="2">
# out_dir,wfkp,Norm = Pkest_Fun(kmin,kmax,nk,nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ra ,dec ,zm ,nb ,FKP,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;raR,decR,zmR,nbRnorm,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;rav,decv,zmv,vp,evp,nbv,FKPv,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;OmegaM,OmegaA,Hub,sigv,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;bulk_vel,PS_type,PS_multi,file_dir,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;wd,wdR,wv)
# </font></font>
# where the keyword:
# - kmin,kmax,nk : set the k-bins of the power spectrum;
# - nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax: set the grid for the survey to measure power spectrum;
# - FKP, FKPv : FKP factors for galaxy and velocity fields, respectively;
# - nb, nbv : galaxy number density for galaxy and velocity fields, respectively;
# - nbRnorm : the number density of randoms for galaxy field (rather than velocity field), narmalized to galaxy numbers.
# - sigv : the intrinsic dispersion of velocities. Usually set to be 300 km/s.
# - PS_type = 'den', 'mom' or 'crs' : for auto-density, auto-momentum or cross- power spectrum, respectively.
# - bulk_vel : the bulk flow velocity of the velocity field.
# - PS_multi = 'all', 'yes' or 'no' : if you want to measure power spectrum multipoles.
# - file_dir,out_dir : the output directory of the measured power spectrum.
# - wfkp : the FKP weights of galaxies;
# - Norm : normalization of power spectrum.
# - wd,wdR,wv : any other weights you want to use for the galaxies, randoms and velocities, respectively. The default value is 1.
#
# We here make the distinction between the positions of galaxies used in defining the density and velocity fields as the galaxies within redshift and peculiar velocity catalogues may not be fully overlapping. (rav,decv,zmv) for velocity catalogue, (ra ,dec ,zm) for galaxy redshift catalogue.
#
# In the output file of the above function, we will have:
# - No :      line number;
# - k :     k-bins;
# - P0, P1, P2, P3, P4 :   measured power spectrum multipoles;
# - Nk        : number of k-mod in each k-bin;
# - Norm      : normalization of power spectrum;
# - SNois  : short-noise of power spectrum.
#
#
# Loading data:

# %%
import numpy as np
import matplotlib.pyplot as plt
from PSestFun import * 

file_dir  = "../Data/" # the directory of data file....
 
# load galaxies and randoms:
raR,decR,zmR     = np.load(file_dir+"rand_ori.npy", allow_pickle=True);                                                         
ra,dec,zm,vp,evp = np.load(file_dir+"data_ori.npy", allow_pickle=True);

# %% [markdown]
# We only have a single catalogue for both the density and velocity fields,
# so (rav, decv, zmv)=(ra ,dec ,zm) for our case!!!
# However, if you have two different catalogues for density and velocity fields,
# you should load the data seperatly:
#
# ra,dec,zm = np.load( ".../galaxy_density.npy", allow_pickle=True); for density velocity field.
#
# rav,decv,zmv,vp,evp = np.load( ".../galaxy_velocity.npy", allow_pickle=True); for velocity field.

# %%
# make some plots to show how the data looks like: 
plt.figure(1,figsize=(8,3))
fsiz=15;tsiz=10
plt.subplot(121)
plt.scatter(raR[:200000],decR[:200000],s=0.1,label='randoms');plt.scatter(ra,dec,s=0.001,label='galaxies');
plt.xlabel('ra',fontsize=fsiz);plt.ylabel('dec',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend(loc='upper right')
plt.subplot(122)
plt.hist(zmR,100,density=True,label='randoms');plt.hist(zm,100,density=True,alpha=0.4,label='galaxies');
plt.xlabel('z',fontsize=fsiz);plt.ylabel('normalized density',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.2, hspace=0.23)
plt.show()

# %% [markdown]
# \
# <font color='brown'><font size="4.9">Section 2.1 Measuring Power Spectrum of Galaxy Survey</font></font>
#
#
#
# In this section, we will show how to measure the density, momentum and cross power spectrum of a volume limited galaxy survey.
#
# <font color='brown'><font size="3.9">2.1.1 The Density Power Spectrum</font></font>

# %%
# the fiducial cosmology
OmegaM = 0.3153     # matter density parameter
OmegaA = 1.-OmegaM  # dark engergy matter density parameter
Hub    = 100.       # Hubble constant

# %% [markdown]
# <font color='blue'>Step 1. calculate the number ratio between the galaxies and randoms:</font>

# %%
D2R_ratio = len(ra)/len(raR)

# %% [markdown]
# <font color='blue'>Step 2. calculate the number density of galaxies:</font> \
# \
# we have two different methods to calculate the number density of galaxies $\bar{n}(\vec{r})$.
# - calculate $\bar{n}(\vec{r})$ on grid, $\bar{n}(\vec{r})$ is a function of sky coverage (ra, dec) and redshift zm.
# - calculate $\bar{n}(\vec{r})$ in shell, $\bar{n}(\vec{r})$ is a function of redshift zm, it is independent of sky coverage (ra, dec).
#
# If the sky coverage and completness of a given survey is complex, we strongly recommand to calculate $\bar{n}(\vec{r})$ on grid. If calculating $\bar{n}(\vec{r})$ on grid, the number of randoms should be large enough to avoid $\bar{n}(\vec{r})=0$. In this notebook, we will compare the above two methods.
#
# The galaxy number density $\bar{n}(\vec{r})$ should be computed from the random catalogue, since $\bar{n}(\vec{r})$ should not have any large-scale-structure infomation and poisson noise. See https://arxiv.org/abs/1910.02914 .
# To do this, we firstly calculate number density of the random catalogue $\bar{n}_{R}(\vec{r})$:
#
# <font color='gray'>(if calculating $\bar{n}(\vec{r})$ on grid)</font>\
# <font color='green'><font size="2">
# nbR_G,NgridDenR,Xlim,Ylim,Zlim = nbarG_Fun(raR,decR,zmR,weight,nbx,nby,nbz,OmegaM,OmegaA,Hub)
# </font></font>
#
# <font color='gray'>(if calculating $\bar{n}(\vec{r})$ in shell)</font>
# <font color='green'><font size="2">
# nbR_S      = nbarS_Fun(delt_z,zmR,weight,SurveyArea,OmegaM,OmegaA,Hub)
# </font></font>
#
# where <font color='green'>weight</font> is the weights of randoms, <font color='green'>delt_z</font> is the thickness of shell, <font color='green'>SurveyArea</font> is the area of the sky coverage of the survey.
# Then calculating galaxy number density $\bar{n}_{g}(\vec{r})$ using $\bar{n}_{R}(\vec{r})$:
#
# <font color='gray'>(if calculating $\bar{n}(\vec{r})$ on grid)</font>\
# <font color='green'><font size="2">
# nb_G = nbarGAsign_Fun( ra,dec,zm,  NgridDenR* D2R_ratio,Xlim,Ylim,Zlim, OmegaM,OmegaA,Hub)
# </font></font>
#
# <font color='gray'>(if calculating $\bar{n}(\vec{r})$ in shell)</font>
# <font color='green'><font size="2">
# nb_S       = nbarSAsign_Fun( zm,zmR,     nbR_S * D2R_ratio   )
# </font></font>
#
# For simplify, we set the weights to be ones.

# %%
weit = 1. # setting the weight of galaxies to be 1 for simplify. 


# method-1. calculate nbar on grid: 
nbx,nby,nbz = 128,128,128 # grid size. 
nbR_G,NgridDenR,Xlim,Ylim,Zlim = nbarG_Fun(raR,decR,zmR,weit,nbx,nby,nbz,OmegaM,OmegaA,Hub)# nbar of randoms.
nb_G = nbarGAsign_Fun( ra,dec,zm,  NgridDenR* D2R_ratio,Xlim,Ylim,Zlim, OmegaM,OmegaA,Hub)# nbar of galaxies.
    
    
# method-2. calculate nbar in shell:
delt_z     = 0.002  # the thickness of shell. 
SurveyArea = 4.*np.pi*0.413159  # the area of sky coverage of the survey. 
nbR_S      = nbarS_Fun(delt_z,zmR,weit,SurveyArea,OmegaM,OmegaA,Hub)# nbar of randoms. 
nb_S       = nbarSAsign_Fun( zm,zmR,     nbR_S * D2R_ratio   )# nbar of galaxies. 

print('Warning: if calculate nbar on grid, there are', len(np.where(nb_G==0)[0]),'galaxies with nbar=0. You may need a larger random catalogue!!!')
# make some plots to see how they looks like:
plt.figure(1,figsize=(8,3))
fsiz=15;tsiz=10
plt.subplot(121)
plt.scatter(zm,nb_G ,s=0.1,label='galaxies, using grid');
plt.scatter(zm,nb_S ,s=0.1,label='galaxies, using shell');
plt.xlabel('redshift',fontsize=fsiz);plt.ylabel(r'$\bar{n}$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(122)
plt.scatter(zmR[:200000],nbR_G[:200000],s=0.1,label='randoms, using grid');
plt.scatter(zmR[:200000],nbR_S[:200000],s=0.1,label='randoms, using shell');
plt.xlabel('redshift',fontsize=fsiz);plt.ylabel(r'$\bar{n}$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.2, hspace=0.23)
plt.show()

# %% [markdown]
# <font color='red'><font size="3.9">Important Tips:</font></font>  The users are encouraged to calculate the number density of galaxies $\bar{n}(\vec{r})$ using their own methods rather than using our naive algorithm.
#
#
#
# <font color='blue'>Step 3. setting k-bins and grid and power spectrum parameters:</font>

# %%
# power spectrum will be measured in k in [0,0.35] for 66 bins. 
kmin,kmax,nk    = 0.0,0.35, 66

# the grid used to grid the galaxies.
nx,ny,nz        = 400,400,400  
xmin,xmax       = -400. ,400. 
ymin,ymax       = -400. ,400.
zmin,zmax       = -400. ,400. 

# FKP weights for density power spectrum. Setting it to be '0' if you do not want any FKP weight.
FKP             = 5000.    

# power spectrum multipoles: 
PS_multi        ='all'  
# 'all'  : will calculate power spectrum for l=0,1,2,3,4
# 'no'   : will calculate power spectrum for l=0 
# 'yes'  : will only calculate the non-zero power spectrum multipoles to save time.
#          i.e. l=0,2,4 for auto-density and auto-momentum power spectrum, 
#               l=1,3   for cross power spectrum.

# %% [markdown]
# <font color='blue'>Step 4. calculate the density power spectrum:</font>

# %%
# 1. if nbar is calculated on grid: 
# setting PS_type='den' for density power. 
out_dir,wfkpG, NormG = Pkest_Fun(kmin,kmax,nk,nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax,
                                ra ,dec ,zm ,nb_G           , FKP,
                                raR,decR,zmR,nbR_G*D2R_ratio, # normalize the nbar of randoms using D2R_ratio. 
                                np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
                                OmegaM,OmegaA,Hub,np.nan, 
                                np.nan,PS_type='den',PS_multi=PS_multi,
                                file_dir=file_dir+'PSden_grid', wd=1., wdR=1.) # wd and wdR are any other weights you want to use for the galaxies and randoms, 
                                                                                                                      # we set them to be 1 for simplify.
# 2. if nbar is calculated on shell: 
out_dir,wfkpS, NormS  = Pkest_Fun(kmin,kmax,nk,nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax,
                                ra ,dec ,zm ,nb_S            ,FKP,
                                raR,decR,zmR,nbR_S*D2R_ratio,
                                np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
                                OmegaM,OmegaA,Hub,np.nan, 
                                np.nan,PS_type='den',PS_multi=PS_multi,
                                file_dir=file_dir+'PSden_shell', wd=1., wdR=1.)
# Out:
#   Please make sure that in the catalogue, observer is at Coordinate origin=[0,0,0]
#
#   den   Ngal= 1786579
#
#   Please make sure that in the catalogue, observer is at Coordinate origin=[0,0,0]
#
#   den   Ngal= 1786579

# %% [markdown]
# In the file of the output, we will have:
# - No :      line number;
# - k :     k-bins;
# - P0, P1, P2, P3, P4 :   measured power spectrum multipoles;
# - Nk        : number of k-mod in each k-bin;
# - Norm      : normalization of power spectrum;
# - SNois  : short-noise of power spectrum.
#
# Read the measured PS:

# %%
# read the measured PS:
infile=np.loadtxt(file_dir+'PSden_grid');
KG=infile[:,1];
P0G=infile[:,2];
P2G=infile[:,4];
P4G=infile[:,6];
infile=np.loadtxt(file_dir+'PSden_shell');
KS=infile[:,1];
P0S=infile[:,2];
P2S=infile[:,4];
P4S=infile[:,6];
# make some plots: 
plt.figure(1,figsize=(12,3))
fsiz=15;tsiz=10
plt.subplot(131)
plt.plot(KG,KG*P0G ,label='nbar using grid');
plt.plot(KS,KG*P0S ,label='nbar using shell');plt.xlim(0,0.33)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$kP_0(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(132)
plt.plot(KG,KG*P2G ,label='nbar using grid');
plt.plot(KS,KG*P2S ,label='nbar using shell');plt.xlim(0,0.33)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$kP_2(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(133)
plt.plot(KG,KG*P4G ,label='nbar using grid');
plt.plot(KS,KG*P4S ,label='nbar using shell');
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$kP_4(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)
plt.xlim(0,0.33)
plt.show()

# %% [markdown]
# <font color='brown'><font size="3.9">2.1.2 The Momentum Power Spectrum</font></font>

# %%
# we assume the bulk flow velocity of the galaxies is 0: 
Bulk_vel= np.array([0.,0.,0.])
sigv    = 300. # km/s is the intrinsic scatter of velocities. 
FKPv    = 10.**10

# 1. if nbar is calculated on grid: 
out_dir,wfkpvG,NormvG= Pkest_Fun(kmin,kmax,nk,nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax,
                                np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
                                ra,dec,zm,vp,evp,nb_G,FKPv,
                                OmegaM,OmegaA,Hub,sigv,
                                bulk_vel=Bulk_vel,PS_type='mom',PS_multi=PS_multi,
                                file_dir=file_dir+'PSmom_grid',wd=np.nan,wdR=np.nan,wv=1. )    
# 2. if nbar is calculated on shell: 
out_dir,wfkpvS,NormvS = Pkest_Fun(kmin,kmax,nk,nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax,
                                np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,
                                ra,dec,zm,vp,evp,nb_S,FKPv,
                                OmegaM,OmegaA,Hub,sigv,
                                bulk_vel=Bulk_vel,PS_type='mom',PS_multi=PS_multi,
                                file_dir=file_dir+'PSmom_shell',wd=np.nan,wdR=np.nan,wv=1. )    

# 3. make plots and read the measured PS:
infile=np.loadtxt(file_dir+'PSmom_grid');
KG=infile[:,1];
P0G=infile[:,2];
P2G=infile[:,4];
P4G=infile[:,6];
infile=np.loadtxt(file_dir+'PSmom_shell');
KS=infile[:,1];
P0S=infile[:,2];
P2S=infile[:,4];
P4S=infile[:,6];
# make some plots: 
plt.figure(1,figsize=(12,3))
fsiz=15;tsiz=10
plt.subplot(131);plt.yscale('log')
plt.plot(KG,P0G ,label='nbar using grid');
plt.plot(KS,P0S ,label='nbar using shell');plt.xlim(0,0.33)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$P_0(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(132);plt.yscale('log')
plt.plot(KG,P2G ,label='nbar using grid');
plt.plot(KS,P2S ,label='nbar using shell');plt.xlim(0,0.33)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$P_2(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(133);plt.yscale('log')
plt.plot(KG,P4G ,label='nbar using grid');
plt.plot(KS,P4S ,label='nbar using shell');
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$P_4(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)
plt.xlim(0,0.33)
plt.show()
# Out:
#   Please make sure that in the catalogue, observer is at Coordinate origin=[0,0,0]
#
#   mom   Npv = 1786579
#
#   Please make sure that in the catalogue, observer is at Coordinate origin=[0,0,0]
#
#   mom   Npv = 1786579

# %% [markdown]
# <font color='brown'><font size="3.9">2.1.3 The Cross Power Spectrum</font></font>
#
# We only have a single catalogue for both the density and velocity fields,
# so (rav, decv, zmv)=(ra ,dec ,zm) for our case!!!

# %%
rav,decv,zmv=ra ,dec ,zm # we only have one survey for den- and vel- field. 

# 1. nbar is calculated on grid: 
out_dir,wfkpcG,NormcG = Pkest_Fun(kmin,kmax,nk,nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax,
                                ra ,dec ,zm ,nb_G,FKP,  
                                raR,decR,zmR,nbR_G*D2R_ratio ,
                                rav,decv,zmv,vp,evp,nb_G,FKPv,   
                                OmegaM,OmegaA,Hub,sigv,
                                bulk_vel=Bulk_vel,PS_type='crs',PS_multi=PS_multi,
                                file_dir=file_dir+'PScrs_grid',wd=1.,wdR=1.,wv=1.)

# 2. nbar is calculated on shell: 
out_dir,wfkpcS,NormcS = Pkest_Fun(kmin,kmax,nk,nx,ny,nz,xmin,xmax,ymin,ymax,zmin,zmax,
                                ra ,dec ,zm ,nb_S,FKP,  
                                raR,decR,zmR,nbR_S*D2R_ratio ,
                                rav,decv,zmv,vp,evp,nb_S,FKPv,   
                                OmegaM,OmegaA,Hub,sigv,
                                bulk_vel=Bulk_vel,PS_type='crs',PS_multi=PS_multi,
                                file_dir=file_dir+'PScrs_shell',wd=1.,wdR=1.,wv=1.)

# 3. make plots and read the measured PS:
infile=np.loadtxt(file_dir+'PScrs_grid');
KG=infile[:,1];
P1G=infile[:,3];
P3G=infile[:,5];
infile=np.loadtxt(file_dir+'PScrs_shell');
KS=infile[:,1];
P1S=infile[:,3];
P3S=infile[:,5];
# make some plots: 
plt.figure(1,figsize=(8,3))
fsiz=15;tsiz=10
plt.subplot(121)
plt.plot(KG,KG*P1G ,label='nbar using grid');
plt.plot(KS,KG*P1S ,label='nbar using shell');plt.xlim(0,0.33)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$kP_1(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(122)
plt.plot(KG,KG*P3G ,label='nbar using grid');
plt.plot(KS,KG*P3S ,label='nbar using shell');plt.xlim(0,0.33)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$kP_3(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.4, hspace=0.23)
plt.xlim(0,0.33)
plt.show()
# Out:
#   Please make sure that in the catalogue, observer is at Coordinate origin=[0,0,0]
#
#   crs   Ngal= 1786579
#   crs   Npv = 1786579
#
#   Please make sure that in the catalogue, observer is at Coordinate origin=[0,0,0]
#
#   crs   Ngal= 1786579
#   crs   Npv = 1786579

# %% [markdown]
# <font color='brown'><font size="4.9">Section 2.2 Measuring Power Spectrum of Randoms</font></font>
#
#
# We need the power spectrum of randoms for window function convolution for the Ross-method.
#
# Call this function:
# <font color='green'><font size="2">
# out_dir, wfkpR  = PkestR_Fun(kminr, kmaxr, nkr,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;nxr, nyr, nzr, xminr, xmaxr, yminr, ymaxr, zminr, zmaxr,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;raR, decR, zmR, evpR, nbR, FKPfactor,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;OmegaM, OmegaA, Hub, sigv, PS_type, file_dir)
# </font></font>

# %%
# grid and k-bin for randoms:
kminr,kmaxr,nkr = 0.0,0.40,350
nxr,nyr,nzr     = 400,400,400 
xminr,xmaxr     = -400. ,400. 
yminr,ymaxr     = -400. ,400.
zminr,zmaxr     = -400. ,400.

# calculate density power spectrum of random data: 
out_dir,wfkpR_S   = PkestR_Fun(kminr,kmaxr,nkr,nxr,nyr,nzr,xminr,xmaxr,yminr,ymaxr,zminr,zmaxr, 
                             raR,decR,zmR,np.nan,nbR_S*D2R_ratio,FKP,
                             OmegaM,OmegaA,Hub,np.nan,'den',file_dir+'PSrand_den')

# calculate momentum power spectrum of random data: 
ravR,decvR,zmvR= raR,decR,zmR
# generating velocity errors for random points 
logd_data = Vp_to_logd(vp,zm,OmegaM) 
NczBin    = 50 # bins of redshift, for calculating the scatter of PVs in each redshift bin.
vpR,evpR  = VpRand_Fun(logd_data,zm*LightSpeed,zmR*LightSpeed,NczBin,OmegaM)
# power spectrum
out_dir,wfkpvR_S  = PkestR_Fun(kminr,kmaxr,nkr,nxr,nyr,nzr,xminr,xmaxr,yminr,ymaxr,zminr,zmaxr, 
                             ravR,decvR, zmvR ,evpR,nbR_S*D2R_ratio,FKPv,
                             OmegaM,OmegaA,Hub,sigv,'mom',file_dir+'PSrand_mom') 

print('They should match!!!')
# make plots and read the measured PS:
infile=np.loadtxt(file_dir+'PSrand_den');
KRden=infile[:,1];
PRden=infile[:,2];
infile=np.loadtxt(file_dir+'PSrand_mom');
KRmom=infile[:,1];
PRmom=infile[:,2];
# make some plots: 
plt.figure(1,figsize=(4,3))
fsiz=15;tsiz=10
plt.loglog(KRden,PRden ,label='density power');
plt.loglog(KRmom,PRmom ,ls='--',label='momentum power');plt.xlim(0,0.4)
plt.xlabel('$log_{10}k$',fontsize=fsiz);plt.ylabel(r'$log_{10}P(k)$',fontsize=fsiz);
plt.tick_params( labelsize =tsiz); plt.legend()
plt.show()
# Out:
#   Random-PS= den
#
#
#   Random-PS= mom
#
# They should match!!!
# /var/folders/f1/cbt1fjn100xdvvn071mfnxlh0000gn/T/ipykernel_58352/2234863786.py:36: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   plt.loglog(KRmom,PRmom ,ls='--',label='momentum power');plt.xlim(0,0.4)

# %% [markdown]
# <font color='brown'><font size="3.9">2.2.1 Some Important Outputs</font></font>
#
#
# We need the following values for window function convolution for CosmPS-Method. We only have one catalogue for both density and velocity field:

# %%
D2R_ratio_v=D2R_ratio # otherwise, you sould calculate them seperatly. 
print('den random/galaxy ratio=',1/D2R_ratio)
print('mom random/galaxy ratio=',1/D2R_ratio_v)
# Out:
# den random/galaxy ratio= 9.953671793970488
# mom random/galaxy ratio= 9.953671793970488

# %% [markdown]
# We need the following values for window function convolution for Pypower-Method

# %%
print('den weight ratio=',np.sum(wfkpR_S)/np.sum(wfkpS[0]))
print('mom weight ratio=',np.sum(wfkpvR_S)/np.sum(wfkpvS[0]))
print('den norm=',NormS)
print('mom norm=',NormvS)
print('crs norm=',NormcS)
# Out:
# den weight ratio= 9.851578578084613
# mom weight ratio= 9.852314385378756
# den norm= 1.7565611037990985
# mom norm= 4.272688735134051e-13
# crs norm= 8.663278155973661e-07

# %% [markdown]
# \
# <font color='brown'><font size="4.9">Section 2.3 Measuring Power Spectrum of Periodic Simulation Box</font></font>
#
# We do not need any random catalogue if measuring power spectrum of Periodic Simulation Box. In our data, the box size is 900 Mpc/h. You can call this funciton:
#
# <font color='green'><font size="2">
# out_dir=Pkest_SimBox_Fun(kmin, kmax, nk, nx, ny, nz, Lbox,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;x, y, z, vx, vy, vz,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;OmegaM, OmegaA, Hub,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;PS_type, PS_multi , file_dir,  wd,  wv)
# </font></font>
#
# where (vx, vy, vz) are the 3D velocities of galaxies.
#
# <font color='red'><font size="3.9">Important Tips:</font></font>  In our code, the coordinate origin should in the center of the simmulation box.

# %%
# load simulation box:
x,y,z,vx,vy,vz=np.load(file_dir+'SimBox_ori.npy', allow_pickle=True);  

# make some plots to show how the data looks like: 
plt.figure(1,figsize=(4,3))
fsiz=15;tsiz=10
plt.scatter(x,y,s=0.001) ;plt.scatter([0,0],[0,0],c='r',s=50);
plt.xlabel('x',fontsize=fsiz);plt.ylabel('y',fontsize=fsiz);plt.tick_params( labelsize =tsiz); 
plt.show()

# %% [markdown]
# In our PS code, the coordinate origin should in the center of the simmulation box.
# So we  need to shift the x,y,z:

# %%
Lbox=900.
x=x-Lbox/2.
y=y-Lbox/2.
z=z-Lbox/2.

# make some plots to show how the data looks like: 
plt.figure(1,figsize=(4,3))
fsiz=15;tsiz=10
plt.scatter(x,y,s=0.001) ;plt.scatter([0,0],[0,0],c='r',s=50);
plt.xlabel('x',fontsize=fsiz);plt.ylabel('y',fontsize=fsiz);plt.tick_params( labelsize =tsiz); 
plt.show()

# %%
# setting parameters:
OmegaM          = 0.3121
OmegaA          = 1.-OmegaM
Hub             = 100.
sigv            = 300.0

kmin,kmax,nk    = 0.0,0.4,90
nx,ny,nz        = 312,312,312
Lbox            = 900.

PS_multi = 'all' 
# density power:
out_dir=Pkest_SimBox_Fun(kmin,kmax,nk,nx,ny,nz,Lbox,  
              x,y,z,vx,vy,vz,
              OmegaM,OmegaA,Hub,
              'den', PS_multi , file_dir+'Sim_PSden',  wd=1. )
# momentum power:
out_dir=Pkest_SimBox_Fun(kmin,kmax,nk,nx,ny,nz,Lbox,  
              x,y,z,vx,vy,vz,
              OmegaM,OmegaA,Hub,
              'mom', PS_multi , file_dir+'Sim_PSmom',  np.nan, wv=1.)
# cross power:
out_dir=Pkest_SimBox_Fun(kmin,kmax,nk,nx,ny,nz,Lbox,  
              x,y,z,vx,vy,vz,
              OmegaM,OmegaA,Hub,
              'crs', PS_multi , file_dir+'Sim_PScrs',  wd=1.,  wv=1. )
# Out:
#   Please make sure that the Coordinate origin=[0,0,0] is in the center of the sim-box.
#
#   den   Ngal= 8403727
#   Please make sure that the Coordinate origin=[0,0,0] is in the center of the sim-box.
#
#   mom   Ngal= 8403727
#   Please make sure that the Coordinate origin=[0,0,0] is in the center of the sim-box.
#
#   crs   Ngal= 8403727

# %%
# loading measured power spectrum and make some plots:
infile=np.loadtxt(file_dir+'Sim_PSden');
kd=infile[:,1];
Pd0=infile[:,2];
Pd2=infile[:,4];
Pd4=infile[:,6];
infile=np.loadtxt(file_dir+'Sim_PSmom');
km=infile[:,1];
Pm0=infile[:,2];
Pm2=infile[:,4];
Pm4=infile[:,6];
infile=np.loadtxt(file_dir+'Sim_PScrs');
kc=infile[:,1];
Pc1=infile[:,3];
Pc3=infile[:,5];

print('Note: the (x,y,z) are real-space positions of galaxies, the measured P(l>=1) is close to 0 !!!')
 
# make some plots: 
plt.figure(1,figsize=(12,3))
fsiz=15;tsiz=10
plt.subplot(131)
plt.plot(kd,kd*Pd0 ,label=r'$\ell=0$');
plt.plot(kd,kd*Pd2 ,label=r'$\ell=2$');
plt.plot(kd,kd*Pd4 ,label=r'$\ell=4$');plt.xlim(0,0.35)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$kP^{\delta}_{\ell}(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(132)
plt.yscale('log')
plt.plot(km,Pm0 ,label=r'$\ell=0$');
plt.plot(km,Pm2 ,label=r'$\ell=2$');
plt.plot(km,Pm4 ,label=r'$\ell=4$');plt.xlim(0,0.35)
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$P^{p}_{\ell}(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplot(133)
plt.plot(kc,kc*Pc1 ,label=r'$\ell=1$');
plt.plot(kc,kc*Pc3 ,label=r'$\ell=3$');
plt.xlabel('k',fontsize=fsiz);plt.ylabel(r'$P^{\delta p}_{\ell}(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); plt.legend()
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)
plt.xlim(0,0.35)
plt.show()
# Out:
# Note: the (x,y,z) are real-space positions of galaxies, the measured P(l>=1) is close to 0 !!!

# %% [markdown]
# <font color='red'><font size="3.9">Important Tips:</font></font> In the simulaiton, the (x,y,z) are real-space positions of galaxies, so the measured $P(k)$ for $\ell>=1$ are close to 0 !!!')
#
#
# \
# Reset Kernal to clean everything !!! ...>>>

# %%
import os
os._exit(00)
# %reset -f

# %% [markdown]
# \
# \
# <font color='brown'><font size="5.9">Part 3. The Window Function Convolution</font></font>
#
# The module we have use for window function covolution is <font color='brown'>PSmodFun.py</font>, to load the module, please run ' <font color='green'> from PSmodFun import * </font>'.
#
# We need random catalogues for both galaxy and velocity surveys to compute window function convolution matrix.

# %%
import gc
import numpy as np
import matplotlib.pyplot as plt
from PSmodFun import * 
# This is the directory to store your input and output data. This string should end with '/'.
file_dir = "../Data/"

# %% [markdown]
# \
# <font color='brown'><font size="4.9">Section 3.1 Ross Method</font></font>
#
# This method only works for $\ell=0$ auto-density and auto-momentum power spectrum.
#
# This method is from Ross et. al 2013: https://arxiv.org/abs/1208.1491 .
#
# Call the following function:
#
# <font color='green'><font size="2">
# WFij, Kmod = ConvMat_Ross( Kmea, kminc, kmaxc, nkbinc, WF_rand, Ncosa, epsilon_par )
# </font></font>
#
# where:
# - Kmea : the k-bin of the measured power spectrum of galaxies.
# - kminc, kmaxc, nkbinc : the k-bin corresponding to the model power spectrum.
# - WF_rand=[kR, PkR] : kR and PkR are the k-bin and power spectrum of randoms.
# - Ncosa : intigration precision of angular $\mu=\cos\theta$.
# - epsilon_par : intigration precision of $k$.
# - WFij : output of window function concolution matrix.
# - Kmod : output of k-bin corresponding to the model power spectrum.

# %%
# seting PS_type to compute window function convolution for density or momentum auto power spectrum, seperately!
PS_type     = 'den'      # 'mom' #             

# 1 read k-bin values of the measured PS of data:
infile=np.loadtxt(file_dir+'PS'+PS_type+'_grid');
k_data=infile[:,1]; NKs= len(k_data)
    
# 2 read PS of randoms: 
infile=np.loadtxt(file_dir+'PSrand_'+PS_type);
k_rand=infile[0:len(infile[:,0])-1,1];Pk_rand=infile[0:len(infile[:,0])-1,2];k_rand[0]=0.0;Pk_rand[0]=1.0
ind=np.where(Pk_rand>0.0);k_rand =k_rand[ind];Pk_rand =Pk_rand[ind]
ind=np.where(Pk_rand>0.0);k_rand =k_rand[ind];Pk_rand =Pk_rand[ind]
    
# 3 extend the ps of randoms:
plt.figure(1,figsize=(4,3))
ktemp,Pktemp=PS_extender(k_rand[1:len(k_rand)],Pk_rand[1:len(k_rand)],100,len(k_rand))
k_rands =np.zeros(1+len(ktemp));Pk_rands=np.zeros(1+len(ktemp))
k_rands[0]=0.0;Pk_rands[0]=1.0
k_rands[1:len(k_rands)]=ktemp;Pk_rands[1:len(k_rands)]=Pktemp
k_rand=k_rands
Pk_rand=Pk_rands
ind=np.where(Pk_rand>0.0)
k_rand =k_rand[ind]
Pk_rand =Pk_rand[ind]
plt.figure(3,figsize=(3,2.5))
fsiz=10;tsiz=8
plt.loglog(k_rand, Pk_rand,marker='',color='r')
plt.xlabel('$k$ [h Mpc$^{-1}$]',fontsize=fsiz);
plt.ylabel('$P_r(k)$',fontsize=fsiz) ;plt.title('Power Spectrum of randoms')
plt.show()     
     
# 4 setting parameters:
Ncosa              = 200              # intigration precision for Ross method only.
epsilon_par        = [0.0,0.8,2000]   # intigration precision and intervel for Ross method only.
Kmea               = k_data[0:NKs-1]  # Ki is for the output, which corresponds to measured PS:
kminc,kmaxc,nkbinc = np.min(Kmea), 0.41, 300   # k_mod bins: the kbin of model PS. 
WF_rand            = [k_rand,Pk_rand] # PS of randoms
    
# 5: The WF matrix WFij is to convert the input model PS(kj) 
# to the output PS(ki):
WFij,Kmod=ConvMat_Ross(Kmea,kminc,kmaxc,nkbinc,WF_rand,Ncosa,epsilon_par)  
np.save(file_dir+'conv'+PS_type+'_'+'Ross',np.array([WFij,Kmea,Kmod,WF_rand],dtype=object),allow_pickle=True)  

# 6: make plots: 
conv,kd,kc,tmp   =np.load(file_dir+'conv'+PS_type+'_'+'Ross'+'.npy',allow_pickle=True)
Nkd=len(kd)//4; indkd=np.array([0.5*Nkd,Nkd,1.5*Nkd,2*Nkd,2.5*Nkd,3*Nkd,3.5*Nkd,4*Nkd],dtype=int)-1        
Nkc=len(kc)//4; indkc=np.array([0.5*Nkc,Nkc,1.5*Nkc,2*Nkc,2.5*Nkc,3*Nkc,3.5*Nkc,4*Nkc],dtype=int)             
plt.figure(3,figsize=(4,3))
fsiz=15;tsiz=8
im   = plt.pcolor( conv   ,    cmap='RdBu_r'   )
cbar = plt.colorbar() ;plt.clim(np.min(conv),  np.max(conv));
cbar.ax.tick_params(labelsize=tsiz); cbar.set_label('$W(k_{mod},k_{mea})$',fontsize=fsiz)  ;
plt.tick_params(axis = 'both', which = 'major', labelsize =tsiz); 
plt.xlabel('$k_{mod}$ [h Mpc$^{-1}$]',fontsize=fsiz);
plt.ylabel('$k_{mea}$ [h Mpc$^{-1}$]',fontsize=fsiz) ;
plt.xticks(indkc,np.round(kc[indkc],3));
plt.yticks(indkd,np.round(kd[indkd],3));
plt.show()

# %% [markdown]
# \
# <font color='brown'><font size="4.9">Section 3.2 CosmPS Method</font></font>
#
# Using the method in Paper III Qin et al. 2024 https://arxiv.org/abs/2411.09571 and Blake et. al. 2018 https://arxiv.org/abs/1801.04969 to calculate the window function convolution matrix for
# power spectrum multipoles.
#
# This method is slow, it will take several hours (~7.5hs) to run the code. Please be patience.
#
# Call the following functions:
#
# <font color='green'><font size="2">
# vpR,evpR  = VpRand_Fun(logd_data,cz_data,cz_rand,NczBin,OmegaM)
# wingrid,weigrid = Prep_winFUN(rand_Ratio,FKPfactor,xR,yR,zR,evpR,wR,sigv,nx,ny,nz,lx,ly,lz,PS_type)
# conv,kmea,kmod   =  ConvMat_CosmPS(kmin,kmax,nkbin,kmaxc,nkbinc,nx,ny,nz,lx,ly,lz,weigridgal,wingridgal ,weigridpv ,wingridpv ,PS_type, kmod_scale)
# </font></font>
#
# where <font color='green'>VpRand_Fun</font>   generates fake peculiar velocities (and errors) for randoms, <font color='green'>Prep_winFUN</font>   grid the randoms, <font color='green'>ConvMat_CosmPS</font>   calculate convolution matrix.
# - logd_data : log-sitance ratio of galaxies.
# - cz_data,cz_rand : redshift in km/s for galaxies and randoms, respectively.
# - rand_Ratio : the number ratio between randoms and galaxies = 1/D2R_ratio.
# - NczBin : number of redshift-bins to cz_data.
# - xR,yR,zR,vpR,evpR,wR : the (x,y,z) positions of randoms, velocities and errors and any other weights of the randoms, respectively.
# - kmin,kmax,nkbin : the k-bin of the measured power spectrum of galaxies.
# - kmaxc,nkbinc : the k-bin corresponding to the model power spectrum.
# - nx,ny,nz,lx,ly,lz: grid parameters.
# - weigridgal,wingridgal : the grid of weighted galaxy density field and un-weighted galaxy density field. Outputs of 'Prep_winFUN'.
# - weigridpv ,wingridpv : the grid of weighted galaxy velocity field and un-weighted galaxy velocity field.Outputs of 'Prep_winFUN'.
# - conv : output of window function concolution matrix.
# - kmea : output of k-bin corresponding to the measured power spectrum.
# - kmod : output of k-bin corresponding to the model power spectrum.
# - kmod_scale= 'lin', 'log': the bin scale for kbins of model power spectrum, linear, log scales.
#
#
# <font color='red'><font size="3.9">Important Tips:</font></font>
# - The nx,ny,nz,nkbinc should not too large, unless the number of random points are large enough to produce a smooth grid for window function grid. Otherwise, <font color='red'>the convolved PS (especially the den-PS) will systmaticly lower than the unconvolved PS.</font>
# - The kmaxc should be slightly larger then kmax, but if kmaxc is much larger then kmax, the convolved PS will has a shift compare to the unconvolved PS. So do not set kmaxc too large, unless the random catalogue is big enough.
# - If 'nkbinc' and/or 'nkbin' is too large, it will cause some numerical precision problems unless the random catalogue is big enough, otherwise, their will be too may '<font color='red'>-1.</font>' values in the matrix 'conv',  '-1.' (euqivlent to 'np.nan' in our code) indicates the k-bin is empty.

# %%
# 1. stetting parameters:
OmegaM      = 0.3151
OmegaA      = 1.0-OmegaM
Hub         = 100.
sigv        = 300.
FKP         = 5000.
FKPv        = 10.**10    
    
nx,ny,nz    = 140  , 140  , 140       # grid parameters
lx,ly,lz    = 700.0, 700.0, 700.0  
    
kmin ,kmax ,nkbin  = 0.0,0.35, 66 
kminc,kmaxc,nkbinc = 0.0,0.41, 170
 
randv_Ratio,randg_Ratio = 9.95367,9.95367  # the number ratio between randoms and galaxies.
                                           # see sectioin 2.2.1.
                                           # randv_Ratio: the number ratio between randoms and PVs
                                           #randg_Ratio: the number ratio between randoms and galaxies
                                           # since we use single catalogue for density and velocity fields
                                           # we have: randv_Ratio=randg_Ratio=1/D2R_ratio
                    
#2 read randoms of den-gal sample:
from PSestFun import *
# load data and randoms
raR,decR,zmR     = np.load(file_dir+"rand_ori.npy", allow_pickle=True);                                                         
ra,dec,zm,vp,evp = np.load(file_dir+"data_ori.npy", allow_pickle=True); 
D2R_ratio=len(ra)/len(raR)
ravR,decvR, zmvR = raR,decR,zmR
weit = 1. # setting the weight of galaxies to be 1 for simplify. 
#calculate nbar on grid: 
delt_z     = 0.002  # the thickness of shell. 
SurveyArea = 4.*np.pi*0.413159  # the area of sky coverage of the survey. 
nbR_S      = nbarS_Fun(delt_z,zmR,weit,SurveyArea,OmegaM,OmegaA,Hub)# nbar of randoms. 
nbRnorm    = nbR_S * len(ra)/len(raR)
# weight density:
randg_weit= 1./(   1.+nbRnorm*FKP)
# generating velocity errors for random points 
logd_data = Vp_to_logd(vp,zm,OmegaM) 
NczBin    = 50 # bins of redshift, for calculating the scatter of PVs in each redshift bin.
vpR,evpR  = VpRand_Fun(logd_data,zm*LightSpeed,zmR*LightSpeed,NczBin,OmegaM)
# weight velocity:
nbvRnorm=nbRnorm
randv_weit= 1./(evpR**2+sigv**2+ nbvRnorm*FKPv) 

#3 convert to cartician, density data:
randg_x,randg_y,randg_z  = Sky2Cat(raR,decR,zmR,OmegaM , OmegaA ,Hub,nbin=20000,redmax=2)   
del raR,decR,zmR,nbRnorm
gc.collect()# save memory
#convert to cartician, velocity data:
randv_x,randv_y,randv_z  = Sky2Cat(ravR,decvR, zmvR ,OmegaM , OmegaA ,Hub,nbin=20000,redmax=2)
del ravR,decvR,zmvR,nbvRnorm
gc.collect()                     

# 4 grid galaxy data and PV data:   
wingridgal,weigridgal = Prep_winFUN(randg_Ratio,FKP,randg_x,randg_y,randg_z,
                                    np.nan,1.,np.nan,nx,ny,nz,lx,ly,lz,'den')  
wingridpv,weigridpv   = Prep_winFUN(randv_Ratio,FKPv,randv_x,randv_y,randv_z,
                                    evpR  ,1.,sigv  ,nx,ny,nz,lx,ly,lz,'mom')

# 5 calculate matrix:  
for i in range(3):
    if(i==0): PS_type     =  'crs'
    if(i==1): PS_type     =  'den' 
    if(i==2): PS_type     =  'mom'  
    print('\n PS_type=',PS_type)          
    if(PS_type=='den'):
        conv,kd,kc   =  ConvMat_CosmPS(kmin,kmax,nkbin,kmaxc,nkbinc,nx,ny,nz,lx,ly,lz,
                                      weigridgal,wingridgal ,weigridgal,wingridgal,PS_type,'log') 
    if(PS_type=='mom'):
        conv,kd,kc   =  ConvMat_CosmPS(kmin,kmax,nkbin,kmaxc,nkbinc,nx,ny,nz,lx,ly,lz,
                                      weigridpv ,wingridpv  ,weigridpv ,wingridpv ,PS_type,'log') 
    if(PS_type=='crs'):
        conv,kd,kc   =  ConvMat_CosmPS(kmin,kmax,nkbin,kmaxc,nkbinc,nx,ny,nz,lx,ly,lz,
                                      weigridgal,wingridgal ,weigridpv ,wingridpv ,PS_type,'log') 
    np.save(file_dir+'conv'+PS_type+'_'+'CosmPS',np.array([conv,kd,kc],dtype=object),allow_pickle=True)
# Out:
#  PS_type= den
# Obtaining convolution for bin 1 of 510 ...
# /Users/fei/WSP/Scie/CosmPSPy/Code/PSmodFun.py:1000: RuntimeWarning: invalid value encountered in divide
#   kphi   = np.where(kgrid>0.,np.arccos(kx[:,np.newaxis,np.newaxis]/kgrid),0.)
# Obtaining convolution for bin 2 of 510 ...
# Obtaining convolution for bin 3 of 510 ...
# Obtaining convolution for bin 4 of 510 ...
# Obtaining convolution for bin 5 of 510 ...
# Obtaining convolution for bin 6 of 510 ...
# Obtaining convolution for bin 7 of 510 ...
# Obtaining convolution for bin 8 of 510 ...
# Obtaining convolution for bin 9 of 510 ...
# Obtaining convolution for bin 10 of 510 ...
# Obtaining convolution for bin 11 of 510 ...
# Obtaining convolution for bin 12 of 510 ...
# Obtaining convolution for bin 13 of 510 ...
# Obtaining convolution for bin 14 of 510 ...
# Obtaining convolution for bin 15 of 510 ...
# Obtaining convolution for bin 16 of 510 ...
# Obtaining convolution for bin 17 of 510 ...
# ...

# %%
# 3 make some plots:
for i in range(3):
    if(i==0):PS_type     =  'crs'
    if(i==1):PS_type     =  'den' 
    if(i==2):PS_type     =  'mom' 
    print('\n PS_type=',PS_type)          
    conv,kd,kc=np.load(file_dir+'conv'+PS_type+'_'+'CosmPS.npy',allow_pickle=True)
    if(PS_type != 'crs'   ):
        plt.figure(3,figsize=(7,5))
        Kd=np.concatenate((kd,kd,kd)) ;Nkd=len(kd)//3; indkd=np.array([Nkd,2*Nkd,3*Nkd,len(kd)+Nkd,len(kd)+2*Nkd,len(kd)+3*Nkd,2*len(kd)+Nkd,2*len(kd)+2*Nkd,2*len(kd)+3*Nkd],dtype=int)-Nkd//2    
        kcut=0.03;Kc0=np.concatenate((kc,kc,kc));kc=kc[kc>=kcut];Kc=np.concatenate((kc,kc,kc)) ;Nkc=len(kc)//3; indkc=np.array([Nkc,2*Nkc,3*Nkc,len(kc)+Nkc,len(kc)+2*Nkc,len(kc)+3*Nkc,2*len(kc)+Nkc,2*len(kc)+2*Nkc,2*len(kc)+3*Nkc],dtype=int)-Nkc//2        
        ind=np.where(Kc0>=kcut)[0];convs=conv[:,ind]      
        fsiz=20;tsiz=10
        im   = plt.pcolor( convs  ,    cmap='RdBu_r'   )
        cbar = plt.colorbar() ;plt.clim(0.8*np.min(conv),  0.7*np.max(conv));
        cbar.ax.tick_params(labelsize=tsiz); cbar.set_label('$W(k_{mod},k_{mea})$',fontsize=fsiz)  ;
        plt.tick_params(axis = 'both', which = 'major', labelsize =tsiz); 
        plt.xlabel('$k_{mod}$ [h Mpc$^{-1}$]',fontsize=fsiz);
        plt.ylabel('$k_{mea}$ [h Mpc$^{-1}$]',fontsize=fsiz) ;
        plt.plot([0,3*len(kc)],[len(kd),len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([0,3*len(kc)],[2*len(kd),2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([0,3*len(kc)],[3*len(kd),3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([len(kc),len(kc)],[0,3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([2*len(kc),2*len(kc)],[0,3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([3*len(kc),3*len(kc)],[0,3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.xticks(indkc,np.round(Kc[indkc],3));
        plt.yticks(indkd,np.round(Kd[indkd],3));
    if(PS_type == 'crs'   ):
        plt.figure(3,figsize=(7,5))
        Kd=np.concatenate((kd,kd)) ;Nkd=len(kd)//3; indkd=np.array([Nkd,2*Nkd,3*Nkd,len(kd)+Nkd,len(kd)+2*Nkd,len(kd)+3*Nkd],dtype=int)-Nkd//2    
        kcut=0.03;Kc0=np.concatenate((kc,kc));kc=kc[kc>=kcut];Kc=np.concatenate((kc,kc)) ;Nkc=len(kc)//3; indkc=np.array([Nkc,2*Nkc,3*Nkc,len(kc)+Nkc,len(kc)+2*Nkc,len(kc)+3*Nkc],dtype=int)-Nkc//2        
        ind=np.where(Kc0>=kcut)[0];convs=conv[:,ind]        
        fsiz=20;tsiz=10
        im   = plt.pcolor( convs  ,    cmap='RdBu_r'   )
        cbar = plt.colorbar() ;plt.clim(0.8*np.min(conv),  0.7*np.max(conv));
        cbar.ax.tick_params(labelsize=tsiz); cbar.set_label('$W(k_{mod},k_{mea})$',fontsize=fsiz)  ;
        plt.tick_params(axis = 'both', which = 'major', labelsize =tsiz); 
        plt.xlabel('$k_{mod}$ [h Mpc$^{-1}$]',fontsize=fsiz);
        plt.ylabel('$k_{mea}$ [h Mpc$^{-1}$]',fontsize=fsiz) ;
        plt.plot([0,2*len(kc)],[len(kd),len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([0,2*len(kc)],[2*len(kd),2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([len(kc),len(kc)],[0,2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([2*len(kc),2*len(kc)],[0,2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.xticks(indkc,np.round(Kc[indkc],3));
        plt.yticks(indkd,np.round(Kd[indkd],3));
    plt.show()
# Out:
#  PS_type= crs
#  PS_type= den
#  PS_type= mom

# %% [markdown]
# In the above plot, kmod is in log-scale rather linear-scale.

# %% [markdown]
# \
# <font color='brown'><font size="4.9">Section 3.3 Pypower Method</font></font>
#
# Using the PYPOWER package: https://github.com/cosmodesi/pypower . To use our code, the users need to install PYPOWER, see https://github.com/cosmodesi/pypower/blob/main/README.md or run:
#
# <font color='brown'>  python -m pip install git+https://github.com/cosmodesi/pypower  </font>
#
#
#
# This method has Wide-angle corrections comparing to CosmPS-method, and it is fast.
#
# Call the following functions:
#
# <font color='green'><font size="2">
# conv,kmea,kmod =  ConvMat_Pypower( Xr,Yr,Zr, weightR,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ngrid,Pk_norm,Weit_Ratio,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kmin,kmax,nkbin,kminc,kmaxc,nkbinc,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ells,boxsize,boxsizes,frac_nyq, PS_type, 'Pypower')
# </font></font>
#
# where:
#
# - Xr,Yr,Zr,weightR: the positions and weights of randoms.
# - boxsize,boxsizes, Ngrid: the gird and size of box.
# - Pk_norm: normalization factor of measured power spectrum.
# - Weit_Ratio: the weight ratio between randoms and galaxies.
# - ells: the $\ell$ for power spectrum multipoles.
# - frac_nyq: Nyquist frequency.
# - kmin,kmax,nkbin    : the k-bin of the measured power spectrum of galaxies.
# - kminc,kmaxc,nkbinc : the k-bin corresponding to the model power spectrum.
# - conv : output of window function concolution matrix.
# - kmea : output of k-bin corresponding to the measured power spectrum.
# - kmod : output of k-bin corresponding to the model power spectrum. It is in log-scale rather linear-scale.

# %%
# 1. stetting parameters:
kmin ,kmax ,nkbin  = 0.0,0.35, 66      
kminc,kmaxc,nkbinc = 0.0,0.41, 3000
Ngrid              = 140
boxsize,boxsizes   = 3*650.0 ,650.0
frac_nyq           = 0.9

WeitRv_Ratio, WeitRg_Ratio = 9.85231, 9.85157 # the FKP weight ratio between randoms and galaxies.
                                              # see sectioin 2.2.1. 
                                              # randv_Ratio: the FKP weight ratio between randoms and PVs
                                              # randg_Ratio: the FKP weight ratio between randoms and galaxies
                                            
Pkden_norm, Pkmom_norm, Pkcrs_norm = 1.756561, 4.272688e-13, 8.663278e-07 # see sectioin 2.2.1.


# 2 calculate matrix:
for i in range(3):
    if(i==0):PS_type     =  'crs'
    if(i==1):PS_type     =  'den' 
    if(i==2):PS_type     =  'mom' 
    print('\n PS_type=',PS_type)          
    if(PS_type=='den'):
        conv,kd,kc   = ConvMat_Pypower( randg_x ,randg_y,randg_z,randg_weit,
                                   Ngrid,Pkden_norm,WeitRg_Ratio,
                                   kmin,kmax,nkbin,kminc,kmaxc,nkbinc,
                                   [0,2,4],boxsize,boxsizes,frac_nyq, PS_type,'Pypower')
    if(PS_type=='mom'):
        conv,kd,kc   = ConvMat_Pypower( randv_x ,randv_y,randv_z,randv_weit,
                                   Ngrid,Pkmom_norm,WeitRv_Ratio,
                                   kmin,kmax,nkbin,kminc,kmaxc,nkbinc,
                                   [0,2,4],boxsize,boxsizes,frac_nyq, PS_type,'Pypower')
    if(PS_type=='crs'):
        NrandRat=[WeitRg_Ratio,WeitRv_Ratio]
        Xr      =[randg_x     ,randv_x] 
        Yr      =[randg_y     ,randv_y]
        Zr      =[randg_z     ,randv_z]
        weitR   =[randg_weit  ,randv_weit]
        conv,kd,kc   =  ConvMat_Pypower( Xr,Yr,Zr, weitR,
                                    Ngrid,Pkcrs_norm,NrandRat,
                                    kmin,kmax,nkbin,kminc,kmaxc,nkbinc, 
                                    [1,3],boxsize,boxsizes,frac_nyq, PS_type,'Pypower')
    np.save(file_dir+'conv'+PS_type+'_'+'Pypower',np.array([conv,kd,kc],dtype=object),allow_pickle=True)
# Out:
# " for i in range(3):\n    if(i==0):PS_type     =  'crs'\n    if(i==1):PS_type     =  'den' \n    if(i==2):PS_type     =  'mom' \n    print('\n PS_type=',PS_type)          \n    if(PS_type=='den'):\n        conv,kd,kc   = ConvMat_Pypower( randg_x ,randg_y,randg_z,randg_weit,\n                                   Ngrid,Pkden_norm,WeitRg_Ratio,\n                                   kmin,kmax,nkbin,kminc,kmaxc,nkbinc,\n                                   [0,2,4],boxsize,boxsizes,frac_nyq, PS_type,'Pypower')\n    if(PS_type=='mom'):\n        conv,kd,kc   = ConvMat_Pypower( randv_x ,randv_y,randv_z,randv_weit,\n                                   Ngrid,Pkmom_norm,WeitRv_Ratio,\n                                   kmin,kmax,nkbin,kminc,kmaxc,nkbinc,\n                                   [0,2,4],boxsize,boxsizes,frac_nyq, PS_type,'Pypower')\n    if(PS_type=='crs'):\n        NrandRat=[WeitRg_Ratio,WeitRv_Ratio]\n        Xr      =[randg_x     ,randv_x] \n        Yr      =[randg_y     ,randv_y]\n       
# ...

# %%
# 3 make some plots:
for i in range(3):
    if(i==0):PS_type     =  'crs'
    if(i==1):PS_type     =  'den' 
    if(i==2):PS_type     =  'mom' 
    print('\n PS_type=',PS_type)          
    conv,kd,kc=np.load(file_dir+'conv'+PS_type+'_'+'Pypower.npy',allow_pickle=True)
    if(PS_type != 'crs'   ):
        plt.figure(3,figsize=(7,5))
        Kd=np.concatenate((kd,kd,kd)) ;Nkd=len(kd)//3; indkd=np.array([Nkd,2*Nkd,3*Nkd,len(kd)+Nkd,len(kd)+2*Nkd,len(kd)+3*Nkd,2*len(kd)+Nkd,2*len(kd)+2*Nkd,2*len(kd)+3*Nkd],dtype=int)-Nkd//2    
        kcut=0.03;Kc0=np.concatenate((kc,kc,kc));kc=kc[kc>=kcut];Kc=np.concatenate((kc,kc,kc)) ;Nkc=len(kc)//3; indkc=np.array([Nkc,2*Nkc,3*Nkc,len(kc)+Nkc,len(kc)+2*Nkc,len(kc)+3*Nkc,2*len(kc)+Nkc,2*len(kc)+2*Nkc,2*len(kc)+3*Nkc],dtype=int)-Nkc//2        
        ind=np.where(Kc0>=kcut)[0];convs=conv[:,ind]      
        fsiz=20;tsiz=10
        im   = plt.pcolor( convs  ,    cmap='RdBu_r'   )
        cbar = plt.colorbar() ;plt.clim(0.8*np.min(conv),  0.7*np.max(conv));
        cbar.ax.tick_params(labelsize=tsiz); cbar.set_label('$W(k_{mod},k_{mea})$',fontsize=fsiz)  ;
        plt.tick_params(axis = 'both', which = 'major', labelsize =tsiz); 
        plt.xlabel('$k_{mod}$ [h Mpc$^{-1}$]',fontsize=fsiz);
        plt.ylabel('$k_{mea}$ [h Mpc$^{-1}$]',fontsize=fsiz) ;
        plt.plot([0,3*len(kc)],[len(kd),len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([0,3*len(kc)],[2*len(kd),2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([0,3*len(kc)],[3*len(kd),3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([len(kc),len(kc)],[0,3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([2*len(kc),2*len(kc)],[0,3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([3*len(kc),3*len(kc)],[0,3*len(kd)],c='w',ls='-.',lw=0.5)
        plt.xticks(indkc,np.round(Kc[indkc],3));
        plt.yticks(indkd,np.round(Kd[indkd],3));
    if(PS_type == 'crs'   ):
        plt.figure(3,figsize=(7,5))
        Kd=np.concatenate((kd,kd)) ;Nkd=len(kd)//3; indkd=np.array([Nkd,2*Nkd,3*Nkd,len(kd)+Nkd,len(kd)+2*Nkd,len(kd)+3*Nkd],dtype=int)-Nkd//2    
        kcut=0.03;Kc0=np.concatenate((kc,kc));kc=kc[kc>=kcut];Kc=np.concatenate((kc,kc)) ;Nkc=len(kc)//3; indkc=np.array([Nkc,2*Nkc,3*Nkc,len(kc)+Nkc,len(kc)+2*Nkc,len(kc)+3*Nkc],dtype=int)-Nkc//2        
        ind=np.where(Kc0>=kcut)[0];convs=conv[:,ind]        
        fsiz=20;tsiz=10
        im   = plt.pcolor( convs  ,    cmap='RdBu_r'   )
        cbar = plt.colorbar() ;plt.clim(0.8*np.min(conv),  0.7*np.max(conv));
        cbar.ax.tick_params(labelsize=tsiz); cbar.set_label('$W(k_{mod},k_{mea})$',fontsize=fsiz)  ;
        plt.tick_params(axis = 'both', which = 'major', labelsize =tsiz); 
        plt.xlabel('$k_{mod}$ [h Mpc$^{-1}$]',fontsize=fsiz);
        plt.ylabel('$k_{mea}$ [h Mpc$^{-1}$]',fontsize=fsiz) ;
        plt.plot([0,2*len(kc)],[len(kd),len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([0,2*len(kc)],[2*len(kd),2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([len(kc),len(kc)],[0,2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.plot([2*len(kc),2*len(kc)],[0,2*len(kd)],c='w',ls='-.',lw=0.5)
        plt.xticks(indkc,np.round(Kc[indkc],3));
        plt.yticks(indkd,np.round(Kd[indkd],3));
    plt.show()
# Out:
#  PS_type= crs
#  PS_type= den
#  PS_type= mom

# %% [markdown]
# In the above plot, kmod is in Geometric-scale rather linear-scale.
#
#
#
#
# \
# Reset Kernal to clean everything !!! ...>>>

# %%
import os
os._exit(00)
# %reset -f

# %% [markdown]
# \
# \
# <font color='brown'><font size="5.9">Part 4. The Theoretical Models of the Redshift-Space Galaxy Power Spectrum</font></font>
#
# \
# <font color='brown'><font size="4.9">Section 4.1 Introduction</font></font>
#
#
#
# In this part, we show some examples for the calculations of the redshift-space galaxy power spectrum models. The code of the models are developed based on the perturbation theory of the following papers:\
# V12: https://arxiv.org/pdf/1207.0839 \
# V13: https://arxiv.org/pdf/1308.6294 \
# O14: https://arxiv.org/pdf/1312.4214v2 \
# S14: https://arxiv.org/abs/1405.1447 \
# H19: https://arxiv.org/pdf/1906.02875 \
# Q19: https://arxiv.org/abs/1906.02874 \
# Q24: https://arxiv.org/abs/2411.09571 \
# Please <font size="4"><font color='red'>cite</font></font> the above papers if you want to use our code to compute the models of galaxy power spectrum.
#
#
# The module we have use to model the power spectrum is <font color='brown'>PSmodFun.py</font>, to load the module, please run ' <font color='green'> from PSmodFun import * </font>'. In this notebook, we will show how to compute:\
#  1: the redshift-space galaxy power spectrum model $P(k,\mu)$; \
#  2: the power spectrum multipole model $P_{\ell}(k )$; \
#  3: the window function convolved power spectrum multipole model $P^c_{\ell}(k )$. \
# We have the auto-density power spectrum $P^{\delta}$, the auto-momentum power spectrum $P^{p}$ and the density-momentum cross-power spectrum $P^{\delta p}$ to compute.
#
# \
# <font color='brown'><font size="4.9">Section 4.2 The Parameters of the Models</font></font>
#
# <font color='brown'><font size="3.9">4.2.1 The Parameters</font></font>
#
# The free parameters of the power spectrum models are listed below. The keywords of the parameters in the code are:
#
# - <font color='blue'>fsigma8</font>    : $f\sigma_8$ the growth rate. It should be larger than zero, $f\sigma_8\in(0,+\infty)$.
# - <font color='blue'>epsilon</font>    : $\epsilon$ a shift on the velocities of galaxies. This parameter is only for the Galilean-transformed auto-momentum and cross-power spectrum. The auto-density power spectrum is not affected by Galilean-transformation. $\epsilon\in(-\infty,+\infty)$, the unite is $km/s$.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<font color='lightpink'> Density field parameters</font>
# - <font color='blue'>b1sigma8</font>   : $b_1\sigma_8$ the first-order biasing parameter of the galaxy density field. It should be larger than zero, $b_1\sigma_8\in(0,+\infty)$.
# - <font color='blue'>b2sigma8</font>   : $b_2\sigma_8$ the second-order local biasing parameter of the galaxy density field, and $b_2\sigma_8\in(-\infty,+\infty)$. It can smaller than zero.
# - <font color='blue'>bssigma8</font>   : $b_s\sigma_8$ the second-order nonlocal biasing parameter of the galaxy density field, $b_s\sigma_8\in(-\infty,+\infty)$. It can smaller than zero too. It comes from the tidal tensor. If setting bssigma8='anal' when fitting the models to the measurments, it will be computed using the local Lagrangian relations, rather than treating it as a free parameter. We strongly recommend the users to set bssigma8='anal' when fitting the models. But anyway, it is up to the users.
# - <font color='blue'>b3nlsigma8</font> : $b_{3nl}\sigma_8$ the third-order nonlocal biasing parameter of the galaxy density field, $b_{3nl}\sigma_8\in(-\infty,+\infty)$.  If setting b3nlsigma8='anal', it will be computed using the local Lagrangian relations.
# - <font color='blue'>sigmav1_squre</font>   : $\sigma^2_{v1}$ the velocity dispersion parameter of the galaxy density field, correspongding to the loop terms $P_{02}$, $P_{12}$, $P_{22}$ and the vector part of $P_{13}$. It should be larger or euqal than zero, $\sigma^2_{v1}\in[0,+\infty)$. The unit is $km^2/s^2$.
# - <font color='blue'>sigmav2_squre</font>   : $\sigma^2_{v2}$ the velocity dispersion parameter of the galaxy density field, correspongding to the loop terms $P_{03}$ and the scalar part of$P_{13}$. $\sigma^2_{v2}\in[0,+\infty)$. The $\ell\ge2$ power spectrum multipole models are sensitive to this parameter. But if the users only want to fit the $\ell=0$ model,  they may want to set its value to be the same as $\sigma^2_{v1}$, i.e. sigmav2_squre=sigmav1_squre. Anyway, it is up to the users. The unit is $km^2/s^2$.
# - <font color='blue'>sigmav3_squre</font>   : $\sigma^2_{v3}$ the velocity dispersion parameter of the galaxy density field, correspongding to the loop term $P_{04}$.  $\sigma^2_{v3}\in[0,+\infty)$. The power spectrum models are not sensitive to this parameter, the users may want to set it to be sigmav3_squre=sigmav1_squre too. The unit is $km^2/s^2$.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<font color='lightpink'>Momentum field parameters</font>
# - <font color='blue'>b1vsigma8</font>   : $b_{v1}\sigma_8$ the first-order biasing parameter of the galaxy velocity field, and $b_1\sigma_8\in(0,+\infty)$.
# - <font color='blue'>b2vsigma8</font>   : $b_{v2}\sigma_8$ the second-order local biasing parameter of the galaxy velocity field, and $b_2\sigma_8\in(-\infty,+\infty)$.  The model of the momentum power spectrum is not sensitive to this parameter, the users can set its value to be the same as the value of the second-order biasing parameter of the density field $b_{2}\sigma_8$, i.e. b2vsigma8=b2sigma8.
# - <font color='blue'>bsvsigma8</font>   : $b_{vs}\sigma_8$ the second-order nonlocal biasing parameter of the velocity field, $b_{vs}\sigma_8\in(-\infty,+\infty)$. If setting bsvsigma8='anal', it will be computed using the local Lagrangian relations. The model of the momentum power spectrum is not sensitive to this parameter, the users can set it to be the same as the density field too, i.e. bsvsigma8=bssigma8 or set it to be bsvsigma8='anal'.
# - <font color='blue'>b3nlvsigma8</font> : $b_{v3nl}\sigma_8$ the third-order nonlocal biasing parameter of the velocity field, $b_{v3nl}\sigma_8\in(-\infty,+\infty)$. If setting b3nlvsigma8='anal', it will be computed using the local Lagrangian relations. The momentum power spectrum model is not sensitive to this parameter, similarly, the users can set it to be b3nlvsigma8=b3nlsigma8 or b3nlvsigma8='anal'.
# - <font color='blue'>sigmavv1_squre</font>   : $\sigma^2_{vv1}$ the velocity dispersion parameter of the velocity field,   $\sigma^2_{vv1}\in[0,+\infty)$. The unit is $km^2/s^2$.
# - <font color='blue'>sigmavv2_squre</font>   : $\sigma^2_{vv2}$ the velocity dispersion parameter of the velocity field, $\sigma^2_{vv2}\in[0,+\infty)$. Similarly, the models of the $\ell\ge2$ power spectrum multipoles are sensitive to this parameter. But if the users only want to fit the $\ell=0$ term, they may set it to be sigmavv2_squre=sigmavv1_squre. The unit is $km^2/s^2$.
# - <font color='blue'>sigmavv3_squre</font>   : $\sigma^2_{vv3}$ the velocity dispersion parameter of the velocity field, $\sigma^2_{vv3}\in[0,+\infty)$. This parameter is not sensitive in the fit, the users may set it to be sigmavv3_squre=sigmavv1_squre. The unit is $km^2/s^2$.
#
# To compute the auto-density power spectrum model, you only need the fsigma8 and the 7 density field parameters. \
# To compute the auto-momentum power spectrum model, you only need the fsigma8 and the 7 momentum field parameters. \
# To compute the cross-power spectrum model, you need 11 parameters:\
# [$f\sigma_8$,$b_1\sigma_8$,$b_2\sigma_8$,$b_s\sigma_8$,$b_{v1}\sigma_8$,$b_{v2}\sigma_8$,$b_{vs}\sigma_8$,$b^c_{3nl}\sigma_8$,$\sigma^2_{cv1}$,$\sigma^2_{cv2}$,$\sigma^2_{cv3}$]\
# where  $b^c_{3nl}\sigma_8$ can either from momentum field or density field, [$\sigma^2_{cv1}$,$\sigma^2_{cv2}$,$\sigma^2_{cv3}$] can either from density field or momentum field.\
# If  $b^c_{3nl}\sigma_8$ is taken from density field, [$\sigma^2_{cv1}$,$\sigma^2_{cv2}$,$\sigma^2_{cv3}$] should be taken from  momentum field, i.e. [$b_{3nl}\sigma_8$, $\sigma^2_{vv1}$, $\sigma^2_{vv2}$, $\sigma^2_{vv3}$].\
# While if  $b^c_{3nl}\sigma_8$ is taken from momentum field, [$\sigma^2_{cv1}$,$\sigma^2_{cv2}$,$\sigma^2_{cv3}$] should  be taken from density field, i.e. [$b_{v3nl}\sigma_8$, $\sigma^2_{v1}$, $\sigma^2_{v2}$, $\sigma^2_{v3}$]. The users can comparing the model cross power to the measured cross power of mocks, to see which one can give better fit results, i.e more close to fiducial parameters. \
# To compute the Galilean-transformed auto-momentum and cross-power spectrum, you need one more free parameter $\epsilon$.
#
#
# <font color='brown'><font size="3.9">4.2.2 Some Suggestions About the Choice of the Free Parameters</font></font>
#
# The power spectrum models are not sensitive to all these parameters in a equal level. So, in a practice level, we can reduce some parameters.
#
# Fitting $P^{\delta}_{0}+P^{p}_{0}$ : \
# We can set ($f\sigma_8$,  $b_1\sigma_8$, $b_2\sigma_8$, $\sigma^2_v$) as free parameters.
# In the meanwhile, setting bssigma8='anal', bsvsigma8='anal', b3nlsigma8='anal', b3nlvsigma8='anal'. All the other  biasing parameters of the momentum field are set to be the same as the density field.  Setting all the  velocity dispersion parameters to be the same vale $\sigma^2_v$.  Therefore, we will only have four free parameters to make the models  flexible enought to fit the measurements.
#
# Fitting $P^{\delta}_{0}+P^{p}_{0}+P^{\delta p}_{1}$: \
# We can set ($f\sigma_8$,  $b_1\sigma_8$, $b_2\sigma_8$, $b_{3nl}\sigma_8$, $\sigma^2_v$) as free parameters.
# In the meanwhile, setting bssigma8='anal', bsvsigma8='anal'. All the other biasing parameters of the momentum field are set to be the same as the density field.  Setting all the  velocity dispersion parameters to be the same vale $\sigma^2_v$.  Therefore, we will only need five free parameters to make the models flexible enought to fit the measurements.
#
# Fitting $P^{\delta}_{02}+P^{p}_{0}+P^{\delta p}_{1}$ : \
# We can set ($f\sigma_8$,  $b_1\sigma_8$, $b_2\sigma_8$, $b_{3nl}\sigma_8$, $b_{v1}\sigma_8$, $\sigma^2_{v1}$, $\sigma^2_{v2}$, $\sigma^2_{vv}$) as free parameters.
# In the meanwhile, setting bssigma8='anal', bsvsigma8='anal', b3nlvsigma8='anal'. All the other biasing parameters of the momentum field are set to be the same as the density field. Setting $\sigma^2_{v3}$ of the density field to be sigmav3_squre=sigmav1_squre.  Setting all the  velocity dispersion parameters of the momentum field to be the same vale $\sigma^2_{vv}$.  Therefore, we will have 8 free parameters to make the models flexible enought to fit the measurements.
#
# Fitting $P^{\delta}_{02}+P^{p}_{02}+P^{\delta p}_{1}$ : \
# We can set ($f\sigma_8$,  $b_1\sigma_8$, $b_2\sigma_8$, $b_{3nl}\sigma_8$, $b_{v1}\sigma_8$, $b_{v2}\sigma_8$, $\sigma^2_{v1}$, $\sigma^2_{v2}$, $\sigma^2_{vv1}$, $\sigma^2_{vv2}$) as free parameters.
# In the meanwhile, setting b3sigma8='anal', b3vsigma8='anal', sigmav3_squre=sigmav1_squre, b3nlvsigma8='anal', sigmavv3_squre=sigmavv1_squre.  Therefore, we will have 10 free parameters to make the models flexible enought to fit the measurements.
#
#
#
# <font color='red'><font size="3.9">Important Tips:</font></font> \
# We strongly recommend the users to set bssigma8='anal' and bsvsigma8='anal' when fittinng the models, rather than setting them as free parameters. \
# The choice of the free parameters are completely up to the users. The users should compare the model to their measurements of mocks to figure out that how many parameters are required to make the model flexible enough to reproduce the fiducial  $f\sigma_8$ of the mocks.

# %% [markdown]
# <font color='brown'><font size="4.9">Section 4.3 Calculating the Redshift-Space Power Spectrum Model $P(k,\mu)$</font></font>
#
# <font color='brown'><font size="3.9">4.3.1 The Redshift-Space Power Spectrum Model $P(k,\mu)$</font></font>
#
# To calculate the redshift-space power spectrum model $P(k,\mu)$, the users can simply copy/paste and run the following 4 lines:
#
# <font color='green'><font size="2">
# from PSmodFun import *  \
# PT, Sig8_fid, outdir&nbsp;= PSloop_Fun( KmodLim,Hub,ombh2,omch2,ns,As,file_dir) \
# az&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= 1./(1.+RsFeff)\
# Hz&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= Hub * Ez(RsFeff, OmegaM, OmegaA, 0., -1., 0., 0.)\
# Dz&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= Dz_Fun(RsFeff, OmegaM, OmegaA, Hub)
# k, mu, Pkmu &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= Pkmod_Fun(parm, Sig8_fid, PT, PS_type, az, Hz,Dz,False,GaliTrans)
# </font></font>
#
#
# where the keyword: \
# PS_type = 'den', 'mom' or 'crs' or 'crsv' for auto-density, auto-momentum or cross- power spectrum, respectively. If using 'crs', in the cross power model, the $b_{3nl}\sigma_8$ will be taken from momentum field, while velocity dispersion parameters will be taken from density field, i.e. using [$b_{v3nl}\sigma_8$, $\sigma^2_{v1}$, $\sigma^2_{v2}$, $\sigma^2_{v3}$] for cross-power model. If using 'crsv', in the cross power model, the $b_{3nl}\sigma_8$ will be taken from momentum field, while velocity dispersion parameters will be taken from density field, i.e. using [$b_{3nl}\sigma_8$, $\sigma^2_{vv1}$, $\sigma^2_{vv2}$, $\sigma^2_{vv3}$] for cross-power model. The users need to use mocks to find out which one can give better fit results.
# az: scale-factor $a(z)$.\
# Dz: growth factor $D(z)$.\
# Hz: Hubble parameter $H(z)$.\
# Hub: Hubble constant at z=0.\
# RsFeff: effective redshift of your data.\
# Ez: This is an internal function of our code, you can directly call it. \
# GaliTrans: True or False, if GaliTrans=True, return the Galilean-transformed power spectrum. The default value if False.
#
# The parameters of the model are encoded in the following order:\
# parm = [ fsigma8 ,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;     b1sigma8 &nbsp;&nbsp;, b2sigma8 &nbsp;&nbsp;, bssigma8&nbsp;&nbsp;, b3nlsigma8 ,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;      b1vsigma8 , b2vsigma8 , bsvsigma8 , b3nlvsigma8 ,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;      sigmav1_squre &nbsp;&nbsp;, sigmav2_squre&nbsp;&nbsp;,  sigmav3_squre ,
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;      sigmavv1_squre , sigmavv2_squre , sigmavv3_squre, (epsilon) ]  . \
# Therefore, <font color='red'><font size="3">the users need to input the parameters in a correct order as shown in the above</font></font>. If 'GaliTrans=True', the users need to set a value for 'epsilon'.
#
#
# In the following, we will show the computation of the model power spectrum step by step. We do not consider the Galilean-transformation.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PSmodFun import * # load the module of the model power spectrum  

# This is the directory to store your input and output data. This string should end with '/'.
file_dir = "../Data/"

# %% [markdown]
# <font color='blue'>Step 1： Calculating the Loop terms: </font>
#
# The 'camb' is used in the following <font color='green'>PSloop_Fun</font> to calculate the real-space linear matter density power spectrum $P_L(k)$. The 'camb' can be downloaded from https://pypi.org/project/camb/ .

# %%
# The cosmological parameters used to calculate the linear matter power spectrum PL(k) of CAMB.
# They should be the same as the fiducial values of the mocks or simulations you want to use.
# For the abacus_cosm000 simulation and mocks, they are in: 
# https://abacussummit.readthedocs.io/en/latest/cosmologies.html
# or Table.1 and 5 of https://www.aanda.org/articles/aa/pdf/2020/09/aa33910-18.pdf
# The fiducial sigma8_fid_sim =0.811355
OmegaM    = 0.315192
OmegaA    = 1.- OmegaM
hb        = 0.67360
Hub       = 100.
ombh2     = 0.02237
omch2     = 0.12000
ns        = 0.96490
As        = 2.1011980518085315e-09
# The 'As' parameter is important, users should adjust it to re-produce the fiducial 'sigma8_fid_sim=0.811355' 
# of the mocks by using the following relation:
# 'As = As*sigma8_fid_sim/sigma8_fid_integ'
# where 'sigma8_fid_integ' is the output value on the screen. 
# Adjust 'As' untill 'sigma8_fid_integ' euqals to 'sigma8_fid_sim'.

#The maximume value of k used to compute PL(k).
KmodLim = 1.  # h/Mpc. Yes, this is a very large value for power spectrum.
NKmodbin= 437 # the number of k-bin for PL(k) of camb.

# You only need to calculate the loop terms 'PT' once for a given set of cosmological parameters, 
# and the results will be automatically saved into "  outdir = file_dir+'INTEG_PL.npy' " after the calculation been finished.
# It will take around 1h30mins to make these calculations on NERSC (but only 20mins on MacBook Pro), please be patience.  
PT, Sig8_fid, outdir = PSloop_Fun( KmodLim,NKmodbin,Hub*hb,ombh2,omch2,ns,As,file_dir) 
print('\n The loop terms are saved in:', outdir, '\n')
# Out:
# sigma8_fid_integ =  [0.81135499]
#
#
#  Integration-Imn
# /Users/fei/WSP/Scie/CosmPSPy/Code/PSmodFun.py:61: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   integ,errin= sp.integrate.quad(Imn_inner_integ,-1.0,1.0,epsabs=0.0,epsrel=1.0e-4,args=(m,n,k,r,Pl_spline))
# /Users/fei/WSP/Scie/CosmPSPy/Code/PSmodFun.py:61: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   integ,errin= sp.integrate.quad(Imn_inner_integ,-1.0,1.0,epsabs=0.0,epsrel=1.0e-4,args=(m,n,k,r,Pl_spline))
# /Users/fei/WSP/Scie/CosmPSPy/Code/PSmodFun.py:61: IntegrationWarning: The integral is probably divergent, or slowly convergent.
# ...

# %% [markdown]
# In the output loop term 'PT', the first colume is the k values of the linear matter power spectrum:\
# klin=PT[0,:] \
# the second colume is the corresponding linear matter power spectrum:\
# Plin=PT[1,:] \
# In the above 'PSloop_Fun', we use CAMB to calculate klin and Plin.

# %%
klin=PT[0,:]
Plin=PT[1,:]
plt.figure(1,figsize=(4,3))
fsiz=15;tsiz=10
plt.loglog(klin,Plin,c='r');
plt.xlabel('k [h/Mpc]',fontsize=fsiz);plt.ylabel('$P_{lin}(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz);
plt.title('Linear matter power spectrum CAMB')
plt.show()

# %% [markdown]
# In addition, the users can use their own linear matter power spectrum as the input to calculate the loop terms use the following function <font color='green'>PSloopInput_Fun</font>:

# %%
# 1. users' Plin:  Linear matter spectra . Here we compromisely use CAMB to simply show an example.
# users can use some other packege rather than CAMB.
klin_usr,Plin_usr,fid_sigma8_usr = CAMB_Fun(1e-4,100.0,NKmodbin,0,Hub*hb,ombh2,omch2,ns, As, False)

# 2. calculate loop terms: 
PTusr, Sig8_fidusr, outdirusr    = PSloopInput_Fun( KmodLim, klin_usr,Plin_usr,fid_sigma8_usr,file_dir+'usr' ) 
print('PT-PTusr = ',np.sum(PT-PTusr));

# 3. make plots:
plt.figure(1,figsize=(4,3))
fsiz=15;tsiz=10
plt.scatter(PT.flatten(),PTusr.flatten(),c='r',s=2);
plt.xlabel('$PT(k)$',fontsize=fsiz);plt.ylabel('user $PT(k)$',fontsize=fsiz);plt.tick_params( labelsize =tsiz); 
plt.title('compare PT to PTusr')
plt.show()
del PTusr, Sig8_fidusr, outdirusr, klin_usr, Plin_usr, fid_sigma8_usr
# Out:
#  Integration-Imn
#
#
#  Integration-Jmn
#
#
#  Integration-Kmn
#
#
#  Integration-Sigma3
#
#
#  Integration-norm
#
# PT-PTusr =  0.0

# %% [markdown]
# <font color='blue'>Step 2： Calculating scale factor $a(z)$ and growth factor $D(z)$ and Hubble parameter $H(z)$ at effective red-shift $z=z_{eff}$: </font>

# %%
RsFeff = 0.05   # An example effective redshift of a survey. It is not for DESI, it should be updated later for DESI PV. 
az     = 1./(1.+RsFeff)
Hz     = Hub * Ez(RsFeff, OmegaM, OmegaA, 0., -1., 0., 0.) # just use Hub = 100. 
Dz     = Dz_Fun(RsFeff, OmegaM, OmegaA )

# %% [markdown]
# <font color='blue'>Step 3： Setting the parameters of power spectrum model: </font>

# %%
# Here we just manually set these parameters, they are not fit results from any real surveys.
# growth rate:------------------
fsigma8        = 0.40946855 
# density field:---------------- 
b1sigma8       = 1.12568620 
b2sigma8       = 1.17890514 
bssigma8       = 'anal' 
b3nlsigma8     = 0.4335061 
sigmav1_squre  = 40.2873740 
sigmav2_squre  = 156.669623 
sigmav3_squre  = 1.8238754 
# momentum field:--------------- 
b1vsigma8      = 0.80151994 
b2vsigma8      = b2sigma8
bsvsigma8      = 'anal'
b3nlvsigma8    = 'anal'
sigmavv1_squre = 3.1344342 
sigmavv2_squre = 12.1289577
sigmavv3_squre = 1.27892345
#-------------------------------
# The list of parameters of power spectrum: 
# As mentioned above, the parameters should be listed in the correct order:
parm = [fsigma8  ,  
        b1sigma8 , b2sigma8 , bssigma8 , b3nlsigma8   ,  
        b1vsigma8, b2vsigma8, bsvsigma8, b3nlvsigma8  ,   
        sigmav1_squre , sigmav2_squre  , sigmav3_squre,    
        sigmavv1_squre, sigmavv2_squre , sigmavv3_squre] 
#-------------------------------
# The list of parameters of Galilean-transformed power spectrum: 
# As mentioned above, the parameters should be listed in the correct order:
epsilon = 200. #km/s
parmG = [fsigma8  ,  
        b1sigma8 , b2sigma8 , bssigma8 , b3nlsigma8   ,  
        b1vsigma8, b2vsigma8, bsvsigma8, b3nlvsigma8  ,   
        sigmav1_squre , sigmav2_squre  , sigmav3_squre,    
        sigmavv1_squre, sigmavv2_squre , sigmavv3_squre, epsilon]

# %% [markdown]
# <font color='blue'>Step 4： Calculating power spectrum model $P(k,\mu)$: </font>

# %%
krsd,mu,Pkmodrsd_den = Pkmod_Fun(parm, Sig8_fid, PT, 'den', az,Hz,Dz,False) # density  auto-power spectrum. 
krsd,mu,Pkmodrsd_mom = Pkmod_Fun(parm, Sig8_fid, PT, 'mom', az,Hz,Dz,False) # momentum auto-power spectrum.
krsd,mu,Pkmodrsd_crs = Pkmod_Fun(parm, Sig8_fid, PT, 'crs', az,Hz,Dz,False) # density-momentum cross-power spectrum.the b3nl will be taken from momentum field, while velocity dispersion parameters will be taken from density field 
krsd,mu,Pkmodrsd_crsv= Pkmod_Fun(parm, Sig8_fid, PT, 'crsv', az,Hz,Dz,False) #density-momentum cross-power spectrum.the b3nl will be taken from density  field, while velocity dispersion parameters will be taken from momentum field

# Galilean-transformed power spectrum: 
krsd,mu,Pkmodrsd_momG = Pkmod_Fun(parmG, Sig8_fid, PT, 'mom', az,Hz,Dz,False, True) # Galilean-transformed momentum auto-power spectrum.
krsd,mu,Pkmodrsd_crsG = Pkmod_Fun(parmG, Sig8_fid, PT, 'crs', az,Hz,Dz,False, True) # Galilean-transformed cross-power spectrum. Just taking 'crs' as example. You can try 'crsv' by yourself.

# %% [markdown]
# In the above, 'krsd' is the wave number $k\in[0,$ KmodLim=$1]$ h/Mpc, 'mu' is the angular $\mu=cos\theta \in[-1,1]$.
#
# The output $P(k,\mu)$, i.e. Pkmodrsd_den, Pkmodrsd_mom and Pkmodrsd_crs are 2D-functions or 2D-images.
#
# The last keyword '<font color='green'>False</font>' is set to compute $P(k,\mu)$, otherwise, the function 'Pkmod_Fun'  will not return $P(k,\mu)$. So please do not change it.
#
# Lets make some plots to see how them look like:

# %%
# Please note that kmax = 1 h/Mpc is a supper large value for power spectrum,  
# and k<0.01 h/Mpc is too small for numerical precision,  
# so, we only want to plot the power spectrum in 0.01<k<0.5 :
indk         = np.where((krsd<=0.43)&(krsd>=0.01))[0]
krsd         = krsd[indk]
Pkmodrsd_den = Pkmodrsd_den[indk,:]
Pkmodrsd_mom = Pkmodrsd_mom[indk,:]
Pkmodrsd_crs = Pkmodrsd_crs[indk,:]
Pkmodrsd_crsv= Pkmodrsd_crsv[indk,:]
Pkmodrsd_momG= Pkmodrsd_momG[indk,:]
Pkmodrsd_crsG= Pkmodrsd_crsG[indk,:]
plt.figure(1,figsize=(32,8))
plt.subplot(131)
im   = plt.imshow( Pkmodrsd_den.T , aspect='0.5',  extent=(np.min(krsd),np.max(krsd),np.min(mu),np.max(mu)), origin='upper',   cmap='RdBu_r', vmin=np.min(Pkmodrsd_den), vmax=np.max(Pkmodrsd_den)  );
cbar = plt.colorbar() ;plt.clim(np.min(Pkmodrsd_den),  np.max(Pkmodrsd_den));cbar.ax.tick_params(labelsize=17); cbar.set_label('$P^{\delta}(k,\mu)$',fontsize=30)  ;plt.ylabel("$\mu$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30); plt.tick_params(axis = 'both', which = 'major', labelsize =25); 
plt.subplot(132)
im   = plt.imshow( Pkmodrsd_mom.T , aspect='0.5',  extent=(np.min(krsd),np.max(krsd),np.min(mu),np.max(mu)), origin='upper',   cmap='RdBu_r', vmin=np.min(Pkmodrsd_mom), vmax=np.max(Pkmodrsd_mom)  );
cbar = plt.colorbar() ;plt.clim(np.min(Pkmodrsd_mom),  np.max(Pkmodrsd_mom));cbar.ax.tick_params(labelsize=17); cbar.set_label('$P^{p}(k,\mu)$',fontsize=30)       ;plt.ylabel("$\mu$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30); plt.tick_params(axis = 'both', which = 'major', labelsize =25); 
plt.subplot(133)
im   = plt.imshow( Pkmodrsd_crs.T , aspect='0.5',  extent=(np.min(krsd),np.max(krsd),np.min(mu),np.max(mu)), origin='upper',   cmap='RdBu_r', vmin=np.min(Pkmodrsd_crs), vmax=np.max(Pkmodrsd_crs)  );
cbar = plt.colorbar() ;plt.clim(np.min(Pkmodrsd_crs),  np.max(Pkmodrsd_crs));cbar.ax.tick_params(labelsize=17); cbar.set_label('$P^{\delta p}(k,\mu)$',fontsize=30);plt.ylabel("$\mu$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30); plt.tick_params(axis = 'both', which = 'major', labelsize =25); 
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.1, hspace=0.23)
plt.show()
# we only plot the mu>=0 parts.
Pkmodrsd_den = Pkmodrsd_den[:,mu>=0]
Pkmodrsd_mom = Pkmodrsd_mom[:,mu>=0]
Pkmodrsd_crs = Pkmodrsd_crs[:,mu>=0]
Pkmodrsd_crsv= Pkmodrsd_crsv[:,mu>=0]
Pkmodrsd_momG= Pkmodrsd_momG[:,mu>=0]
Pkmodrsd_crsG= Pkmodrsd_crsG[:,mu>=0]
# plots:
print('\n \n if only plot the mu>=0, we get:')
plt.figure(2,figsize=(32,8))
plt.subplot(131)
im   = plt.imshow( Pkmodrsd_den.T , aspect='0.5',  extent=(np.min(krsd),np.max(krsd),np.min(mu),np.max(mu)), origin='upper',   cmap='RdBu_r', vmin=np.min(Pkmodrsd_den), vmax=np.max(Pkmodrsd_den)  );
cbar = plt.colorbar() ;plt.clim(np.min(Pkmodrsd_den),  np.max(Pkmodrsd_den));cbar.ax.tick_params(labelsize=17); cbar.set_label('$P^{\delta}(k,\mu)$',fontsize=30)  ;plt.ylabel("$\mu$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30); plt.tick_params(axis = 'both', which = 'major', labelsize =25); 
plt.subplot(132)
im   = plt.imshow( Pkmodrsd_mom.T , aspect='0.5',  extent=(np.min(krsd),np.max(krsd),np.min(mu),np.max(mu)), origin='upper',   cmap='RdBu_r', vmin=np.min(Pkmodrsd_mom), vmax=np.max(Pkmodrsd_mom)  );
cbar = plt.colorbar() ;plt.clim(np.min(Pkmodrsd_mom),  np.max(Pkmodrsd_mom));cbar.ax.tick_params(labelsize=17); cbar.set_label('$P^{p}(k,\mu)$',fontsize=30)       ;plt.ylabel("$\mu$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30); plt.tick_params(axis = 'both', which = 'major', labelsize =25); 
plt.subplot(133)
im   = plt.imshow( Pkmodrsd_crs.T , aspect='0.5',  extent=(np.min(krsd),np.max(krsd),np.min(mu),np.max(mu)), origin='upper',   cmap='RdBu_r', vmin=np.min(Pkmodrsd_crs), vmax=np.max(Pkmodrsd_crs)  );
cbar = plt.colorbar() ;plt.clim(np.min(Pkmodrsd_crs),  np.max(Pkmodrsd_crs));cbar.ax.tick_params(labelsize=17); cbar.set_label('$P^{\delta p}(k,\mu)$',fontsize=30);plt.ylabel("$\mu$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30); plt.tick_params(axis = 'both', which = 'major', labelsize =25); 
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.1, hspace=0.23)
# Out:
#
#  if only plot the mu>=0, we get:

# %% [markdown]
# \
# <font color='brown'><font size="3.9">4.3.2 Convert the 2D Power Spectrum $P(k,\mu)$ to 1D Power Spectrum $P(k)$</font></font>
#
# We can convert the 2D power spectrum $P(k,\mu)$ to 1D power spectrum $P(k)$ by integral $P(k,\mu)$ over $\mu$:
# $$P(k)=\int^1_0P(k,\mu)d\mu$$
# We can use the Simpson's rule:

# %%
Pk_den = sp.integrate.simps(Pkmodrsd_den,mu[mu>=0],axis=1);
Pk_mom = sp.integrate.simps(Pkmodrsd_mom,mu[mu>=0],axis=1);
Pk_crs = sp.integrate.simps(Pkmodrsd_crs,mu[mu>=0],axis=1);
Pk_crsv= sp.integrate.simps(Pkmodrsd_crsv,mu[mu>=0],axis=1);
# Galilean-transformed power spectrum: 
Pk_momG = sp.integrate.simps(Pkmodrsd_momG,mu[mu>=0],axis=1);
Pk_crsG = sp.integrate.simps(Pkmodrsd_crsG,mu[mu>=0],axis=1);


# make some plots:
plt.figure(2,figsize=(45,9))
plt.subplot(131)
plt.plot(krsd,krsd*Pk_den);plt.ylabel("$kP^{\delta}(k)$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30);plt.tick_params( labelsize =25); plt.xlim(0,0.44); plt.ylim(0,2000)
plt.subplot(132)
plt.yscale('log');
plt.plot(krsd, Pk_mom,label='mom-PS');
plt.plot(krsd, Pk_momG,label='Galilean-transformed mom-PS');plt.legend(fontsize=30)
plt.ylabel("$P^{p}(k)$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30);plt.tick_params( labelsize =25); plt.xlim(0,0.44);  
plt.subplot(133)
plt.plot(krsd, krsd*Pk_crs,label='crs');
plt.plot(krsd, krsd*Pk_crsv,label='crsv');
plt.plot(krsd, krsd*Pk_crsG,label='Galilean-transformed crs');plt.legend(fontsize=30)
plt.ylabel("$kP^{\delta p}(k)$",fontsize=30);plt.xlabel("$k$ [h/Mpc]",fontsize=30);plt.tick_params( labelsize =25); plt.xlim(0,0.44); plt.ylim(-400000,1200000)
plt.subplots_adjust(left=0.125,bottom=0.1, right=0.9, top=0.9, wspace=0.28, hspace=0.23)

# %% [markdown]
# \
# \
# <font color='brown'><font size="4.9">Section 4.4 Calculating the Power Spectrum Multipole Model $P_{\ell}(k )$</font></font>
#
# To calculate the power spectrum multipole model $P_{\ell}(k )$, the users can simply copy/paste and run the following 4 lines:
#
# <font color='green'><font size="2">
# from PSmodFun import *  \
# PT, Sig8_fid, outdir&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= PSloop_Fun( KmodLim,Hub,ombh2,omch2,ns,As,file_dir) \
# az&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= 1./(1.+RsFeff)\
# Hz&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= Hub * Ez(RsFeff, OmegaM, OmegaA, 0., -1., 0., 0.)\
# Dz&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= Dz_Fun(RsFeff, OmegaM, OmegaA, Hub)
# Pkmulti ,kmulti, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, np.nan,np.nan,np.nan, PT, PS_type, az,Hz,Dz, np.nan,GaliTrans)
# </font></font>
#
# where where the keywords are:
#
# PS_type = 'den-024', 'mom-024' or 'crs-13' or 'crsv-13' for auto-density, auto-momentum or cross- power spectrum, respectively.
#
#
# kbin : the k values the users want to use for the computation of power spectrum.
#
# tmp: cache which is not important, the users can ignore this.

# %%
# As mentioned before, we only need to calculate the loop term once, 
# therefore, in here, we directly load the loop terms from file.
sst          = np.load(file_dir+'INTEG_PL.npy',allow_pickle=True)
PT, Sig8_fid = sst  

# set k-bins:
Nk           = 1000
kbin         = np.linspace(0.01,0.42,Nk )

# calculate Power Spectrum Multipole Models:
# density ps:
Pkmulti_den,kmulti_den, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, 
                                                 np.nan,np.nan,np.nan, PT, 'den-024', az,Hz,Dz, np.nan)
# mom ps:
Pkmulti_mom,kmulti_mom, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, 
                                                 np.nan,np.nan,np.nan, PT, 'mom-024', az,Hz,Dz, np.nan)
# crs ps:
Pkmulti_crs,kmulti_crs, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, 
                                                 np.nan,np.nan,np.nan, PT, 'crs-13' , az,Hz,Dz, np.nan) 

#make some plots:
plt.figure(4,figsize=(18,6))
plt.subplot(131)
plt.plot(kmulti_den[0*Nk:1*Nk]  ,kmulti_den[0*Nk:1*Nk] * Pkmulti_den[0*Nk:1*Nk]  ,c='r' ,label='$\ell=0$');
plt.plot(kmulti_den[1*Nk:2*Nk]  ,kmulti_den[1*Nk:2*Nk] * Pkmulti_den[1*Nk:2*Nk]  ,c='g' ,label='$\ell=2$');
plt.plot(kmulti_den[2*Nk:3*Nk]  ,kmulti_den[2*Nk:3*Nk] * Pkmulti_den[2*Nk:3*Nk]  ,c='b' ,label='$\ell=4$');
plt.legend(fontsize=18); plt.xticks(fontsize=18); plt.yticks(fontsize=18); plt.xlim(0,0.44);plt.ylim(-550,2300);
plt.ylabel('$P^{\delta}_{\ell}(k)$',fontsize=23);plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.subplot(132)
plt.yscale('log')
plt.plot(kmulti_mom[0*Nk:1*Nk],Pkmulti_mom[0*Nk:1*Nk]  ,c='r',label='$\ell=0$');
plt.plot(kmulti_mom[1*Nk:2*Nk],Pkmulti_mom[1*Nk:2*Nk]  ,c='g',label='$\ell=2$');
plt.plot(kmulti_mom[2*Nk:3*Nk],Pkmulti_mom[2*Nk:3*Nk]  ,c='b',label='$\ell=4$');
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{\ell}(k)$',fontsize=23);plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23);plt.xlim(0,0.44)
plt.subplot(133)
plt.plot(kmulti_crs[0*Nk:1*Nk]  ,kmulti_crs[0*Nk:1*Nk] * Pkmulti_crs[0*Nk:1*Nk]  ,c='y' ,label='$\ell=1$');
plt.plot(kmulti_crs[1*Nk:2*Nk]  ,kmulti_crs[1*Nk:2*Nk] * Pkmulti_crs[1*Nk:2*Nk]  ,c='pink' ,label='$\ell=3$');
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta p}_{\ell}(k)$',fontsize=23);plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23);plt.xlim(0,0.44);plt.ylim(-1000000,2*10**6)
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)

# %% [markdown]
# \
# \
# <font color='brown'><font size="4.9">Section 4.5 Calculating the Window Function Convolved Power Spectrum Multipole Model $P^c_{\ell}(k )$</font></font>
#
# To calculate the window function convolved power spectrum multipole $P^c_{\ell}(k )$, the users can simply copy/paste and run the following 4 lines:
#
# <font color='green'><font size="2">
# from PSmodFun import *  \
# PT, Sig8_fid, outdir&nbsp;&nbsp;= PSloop_Fun( KmodLim,Hub,ombh2,omch2,ns,As,file_dir) \
# az&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= 1./(1.+RsFeff)\
# Hz&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= Hub * Ez(RsFeff, OmegaM, OmegaA, 0., -1., 0., 0.)\
# Dz&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;= Dz_Fun(RsFeff, OmegaM, OmegaA, Hub)\
# Pkmulti_conv ,kmulti_conv, Pkmulti ,kmulti = PkmodMulti_Fun(parm, OnlyL0, Sig8_fid, kdata , kmod ,\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ConvolutionMatrix,WF_rand, PT, PS_type, az,Hz,Dz, ConvolutionMethod, model_type,GaliTrans )
# </font></font>
#
# where the keywords are:
#
# PS_type='den-024', 'mom-024' or 'crs-13' or 'crsv-13' for auto-density, auto-momentum or cross- power spectrum, respectively.
#
# ConvolutionMethod :  'CosmPS', 'Pypower' or 'Ross' for three different convolution methods.
#
# OnlyL0 : if using the Ross convolution method, i.e. ConvolutionMethod='Ross', set OnlyL0=True, otherwise, set OnlyL0=False.
#
# ConvolutionMatrix: the window function convolution matrix.
#
# model_type : 'lin' using Kaiser formular, 'nolin' perterbation models.
#
# WF_rand: only for ConvolutionMethod='Ross',  otherwise, set WF_rand=np.nan .
#
# kdata: the k-bin of the measured power spectrum.
#
# kmod: the k-bin of the original model power spectrum.
#
# Pkmulti_conv ,kmulti_conv : the concolved power spectrum model.
#
# Pkmulti ,kmulti     : the corresponding original power spectrum model.
#
# The users need the window function convolution matrix for this section. The matrix is computed in other code rather than in this code.

# %%
# loading convolution matrix from files, they have been pre-computed: 
# Ross method:
covrossden, k_datar, k_modr, WF_rand = np.load(file_dir+'convden_Ross.npy',allow_pickle=True) 
covrossmom, k_datar, k_modr, WF_rand = np.load(file_dir+'convmom_Ross.npy',allow_pickle=True) 
# CosmPS method:
covden    , kdatab,  kmodb          = np.load(file_dir+'convden_CosmPS.npy',allow_pickle=True) 
covmom    , kdatab,  kmodb          = np.load(file_dir+'convmom_CosmPS.npy',allow_pickle=True) 
covcrs    , kdatab,  kmodb          = np.load(file_dir+'convcrs_CosmPS.npy',allow_pickle=True)
covCosmPS                           = [covden,covmom,covcrs]
Nkmod    = len(kmodb) 
Nkdat    = len(kdatab)
# Pypower: 
covden    , kdatap,  kmodp          = np.load(file_dir+'convden_Pypower.npy',allow_pickle=True) 
covmom    , kdatap,  kmodp          = np.load(file_dir+'convmom_Pypower.npy',allow_pickle=True) 
covcrs    , kdatap,  kmodp          = np.load(file_dir+'convcrs_Pypower.npy',allow_pickle=True)
covpypw                             = [covden,covmom,covcrs]
Nkdatp   = len(kdatap)
# build k-bins: 
k_datab  = np.concatenate(np.array([list(kdatab),list(kdatab),list(kdatab)]))
k_datap  = np.concatenate(np.array([list(kdatap),list(kdatap),list(kdatap)]))
k_modb   =                np.array([list(kmodb) ,list(kmodb) ,list(kmodb)])
k_modp   =                np.array([list(kmodp) ,list(kmodp) ,list(kmodp)])
 

# calculate the window function convolved power spectrum multipoles:
# density power: 
Pkmodc_denrg,kmodc_denrg,Pkmod_denrg,kmod_denrg = PkmodMulti_Fun(parm,True , Sig8_fid, k_datar , k_modr,  covrossden , WF_rand, PT, 'den-0'  , az,Hz,Dz, 'Ross' )
Pkmodc_denb ,kmodc_denb ,Pkmod_denb ,kmod_denb  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datab , k_modb,  covCosmPS  , np.nan , PT, 'den-024', az,Hz,Dz, 'CosmPS' )
Pkmodc_denp ,kmodc_denp ,Pkmod_denp ,kmod_denp  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datap , k_modp,  covpypw    , np.nan , PT, 'den-024', az,Hz,Dz, 'Pypower' )
# momentum power: 
Pkmodc_momrg,kmodc_momrg,Pkmod_momrg,kmod_momrg = PkmodMulti_Fun(parm,True , Sig8_fid, k_datar , k_modr,  covrossden , WF_rand, PT, 'mom-0'  , az,Hz,Dz, 'Ross' )
Pkmodc_momb ,kmodc_momb ,Pkmod_momb ,kmod_momb  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datab , k_modb,  covCosmPS  , np.nan , PT, 'mom-024', az,Hz,Dz, 'CosmPS' )
Pkmodc_momp ,kmodc_momp ,Pkmod_momp ,kmod_momp  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datap , k_modp,  covpypw    , np.nan , PT, 'mom-024', az,Hz,Dz, 'Pypower' )
# cross    power: 
Pkmodc_crsb ,kmodc_crsb ,Pkmod_crsb ,kmod_crsb  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datab , k_modb,  covCosmPS  , np.nan , PT, 'crs-13' , az,Hz,Dz, 'CosmPS' )
Pkmodc_crsp ,kmodc_crsp ,Pkmod_crsp ,kmod_crsp  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datap , k_modp,  covpypw    , np.nan , PT, 'crs-13' , az,Hz,Dz, 'Pypower' )





# make plots:================================================================
plt.figure(5,figsize=(18,6))
plt.subplot(131)
plt.plot(kmod_denb[0*Nkmod:1*Nkmod]   , kmod_denb[0*Nkmod:1*Nkmod]   * Pkmod_denb[0*Nkmod:1*Nkmod]    ,c='silver',lw=4, label='Original Model PS')
plt.plot(kmodc_denrg                  , kmodc_denrg                  * Pkmodc_denrg                   ,c='lime',label='Conv PS Ross')
plt.plot(kmodc_denb[0*Nkdat:1*Nkdat]  , kmodc_denb[0*Nkdat:1*Nkdat]  * Pkmodc_denb[0*Nkdat:1*Nkdat]   ,c='orangered' ,  label='Conv PS CosmPS')
plt.plot(kmodc_denp[0*Nkdatp:1*Nkdatp], kmodc_denp[0*Nkdatp:1*Nkdatp]* Pkmodc_denp[0*Nkdatp:1*Nkdatp] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta}_{0}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43);#plt.ylim(0,1500)
plt.subplot(132)
plt.plot(kmod_denb[1*Nkmod:2*Nkmod]    ,kmod_denb[1*Nkmod:2*Nkmod]   * Pkmod_denb[1*Nkmod:2*Nkmod]    ,c='silver',lw=4, label='Original Model PS')
plt.plot(kmodc_denb[1*Nkdat:2*Nkdat]   ,kmodc_denb[1*Nkdat:2*Nkdat]  * Pkmodc_denb[1*Nkdat:2*Nkdat]   ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_denp[1*Nkdatp:2*Nkdatp] ,kmodc_denp[1*Nkdatp:2*Nkdatp]* Pkmodc_denp[1*Nkdatp:2*Nkdatp] ,c='deepskyblue',label='Conv PS pypower')
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.xlim(0,0.43);plt.ylim(-550,800)
plt.ylabel('k $P^{\delta}_{2}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.subplot(133)
plt.plot(kmod_denb[2*Nkmod:3*Nkmod]    ,kmod_denb[2*Nkmod:3*Nkmod]   * Pkmod_denb[2*Nkmod:3*Nkmod]    ,c='silver',lw=4, label='Original Model PS')
plt.plot(kmodc_denb[2*Nkdat:3*Nkdat]   ,kmodc_denb[2*Nkdat:3*Nkdat]  * Pkmodc_denb[2*Nkdat:3*Nkdat]   ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_denp[2*Nkdatp:3*Nkdatp] ,kmodc_denp[2*Nkdatp:3*Nkdatp]* Pkmodc_denp[2*Nkdatp:3*Nkdatp] ,c='deepskyblue',label='Conv PS pypower')
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.xlim(0,0.43);plt.ylim(-100,100)
plt.ylabel('k $P^{\delta}_{4}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)

plt.figure(6,figsize=(18,6))
plt.subplot(131)
plt.yscale('log')
plt.plot(kmod_momb[0*Nkmod:1*Nkmod]  , Pkmod_momb[0*Nkmod:1*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_momrg                 , Pkmodc_momrg                 ,c='lime',label='Conv PS Ross')
plt.plot(kmodc_momb[0*Nkdat:1*Nkdat] , Pkmodc_momb[0*Nkdat:1*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_momp[0*Nkdat:1*Nkdat] , Pkmodc_momp[0*Nkdat:1*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{0}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43)
plt.subplot(132)
plt.yscale('log')
plt.plot(kmod_momb[1*Nkmod:2*Nkmod]  , Pkmod_momb[1*Nkmod:2*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_momb[1*Nkdat:2*Nkdat] , Pkmodc_momb[1*Nkdat:2*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_momp[1*Nkdat:2*Nkdat] , Pkmodc_momp[1*Nkdat:2*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{2}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43)
plt.subplot(133)
plt.yscale('log')
plt.plot(kmod_momb[2*Nkmod:3*Nkmod]  , Pkmod_momb[2*Nkmod:3*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_momb[2*Nkdat:3*Nkdat] , Pkmodc_momb[2*Nkdat:3*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_momp[2*Nkdat:3*Nkdat] , Pkmodc_momp[2*Nkdat:3*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{4}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43)
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)
 
plt.figure(7,figsize=(9,5))
plt.subplot(131)
plt.plot(kmod_crsb[0*Nkmod:1*Nkmod]  ,kmod_crsb[0*Nkmod:1*Nkmod] * Pkmod_crsb[0*Nkmod:1*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_crsb[0*Nkdat:1*Nkdat] ,kmodc_crsb[0*Nkdat:1*Nkdat]* Pkmodc_crsb[0*Nkdat:1*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_crsp[0*Nkdat:1*Nkdat] ,kmodc_crsp[0*Nkdat:1*Nkdat]* Pkmodc_crsp[0*Nkdat:1*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta p}_{1}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43);plt.ylim(-0.7*10**6,2*10**6)
plt.subplot(132)
plt.plot(kmod_crsb[1*Nkmod:2*Nkmod]    ,kmod_crsb[1*Nkmod:2*Nkmod]   * Pkmod_crsb[1*Nkmod:2*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_crsb[1*Nkdat:2*Nkdat]   ,kmodc_crsb[1*Nkdat:2*Nkdat]  * Pkmodc_crsb[1*Nkdat:2*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_crsp[1*Nkdatp:2*Nkdatp] ,kmodc_crsp[1*Nkdatp:2*Nkdatp]* Pkmodc_crsp[1*Nkdatp:2*Nkdatp] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta p}_{3}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43);plt.ylim(-6*10**5,0.3*10**6)
plt.subplots_adjust(left=0.125,bottom=0.1, right=2.5, top=0.9, wspace=0.35, hspace=0.23)

# %% [markdown]
#
# \
# <font color='brown'><font size="4.9">Section 4.6 Comparing the Perturbation Models to Kaiser Formulars</font></font>
#
# We compare our perterbation (non-linear) model power spectrum to the linear model power spectrum - Kaiser formulars:\
# density-PS: $$P(k)=(b_1+f\mu^2)^2D^2_gP_L(k)$$
# momentum-PS: $$P(k)=(\frac{aHf\mu}{k})^2D^2_pP_L(k)$$
# cross-PS: $$P(k)=(b_1+f\mu^2)(\frac{aHf\mu}{k})D_gD_pP_L(k)$$
# where $P_L(k)$ is the linear matter power spectrum from CAMB, and the damping terms are:\
# density field: $$D_g=[1+0.5(k\mu \sigma_{v,g})^2]^{-1/2}$$
# velocity field: $$D_v=sinc(k\sigma_{v,p})=\frac{sin(k\sigma_{v,p})}{k\sigma_{v,p}}$$
#
# <font color='red'><font size="4">Important Tips:</font></font>
# - Setting the higher order parameters (e.g. b2, bs, b3, sigv2 and sigv3 ...) of the non-linear model power spectrum all to be zeros can <font color='red'>NOT</font> make our non-linear linear. In the meanwhile, we should also set the non-linear loop terms to be zeros using <font color='green'>PT[2:,:]=np.zeros(len(PT[0,:]))</font> to linearized our non-linear models.
# - Regarding the <font color='red'>density</font>  power spectrum, the linearized perturbation model only consistent with the Kaiser Formular at redshift zero, i.e. $a(z=0)=1$ or Growthz=1, since the non-linear model density power spectrum is a function of $a(z)$, but in the Kaiser Formular, the density power spectrum is independent of  $a(z)$. So, we only comparing the linearized density power spectrum model to Kaiser formular at z=0 by setting Growthz=1.
#
# For simplify, we set $\sigma_v=0$ in Kaiser formular, therefore, there is not damping.
#
# \
# <font color='brown'><font size="3.9">4.6.1 Comparing 2D Power Spectrum $P(k, \mu)$</font></font>

# %%
fsigma8       = 0.437
b1sigma8      = 1.464


# 1. Prepare linear matter power spectrum:
sst          = np.load(file_dir+'INTEG_PL.npy',allow_pickle=True)
PT, Sig8_fid = sst 
Plin = PT[1,:]
klin = PT[0,:]


# 2: making our nonlinaer-model linear: 
PTlin=PT+0.-0.
PTlin[2:,:]=np.zeros(len(PT[0,:]))
parm = [fsigma8, b1sigma8, 0, 0, 0,  b1sigma8, 0,0,0,0,0,0,0,0,0]
k,mu,Pden  = Pkmod_Fun(parm, Sig8_fid, PTlin, 'den', 1.,100.,1.,False) # I set scale-factor a(z)=1, H(z)=100, D(z)=1.
k,mu,Pmom  = Pkmod_Fun(parm, Sig8_fid, PTlin, 'mom', 1.,100.,1.,False)  
k,mu,Pcrs  = Pkmod_Fun(parm, Sig8_fid, PTlin, 'crs', 1.,100.,1.,False)  
indk       = np.where((k<=0.5)&(k>=0.01))[0]
k    = k[indk]
Pden = Pden[indk,:]
Pmom = Pmom[indk,:]
Pcrs = Pcrs[indk,:]
# integral over \mu: 
Pden_lin = sp.integrate.simps(Pden[:,mu>=0],mu[mu>=0],axis=1);
Pmom_lin = sp.integrate.simps(Pmom[:,mu>=0],mu[mu>=0],axis=1);
Pcrs_lin = sp.integrate.simps(Pcrs[:,mu>=0],mu[mu>=0],axis=1);


# 3: kaiser formulars:
parm = [fsigma8, b1sigma8, 0, 0]
k,mu,Pden_Kaiser=Pkmod_Kaiser_Fun(parm,Sig8_fid,klin,Plin,'den', 1.,100.,  False )   # I set scale-factor a(z)=1, H(z)=100.  
k,mu,Pmom_Kaiser=Pkmod_Kaiser_Fun(parm,Sig8_fid,klin,Plin,'mom', 1.,100.,  False )  
k,mu,Pcrs_Kaiser=Pkmod_Kaiser_Fun(parm,Sig8_fid,klin,Plin,'crs', 1.,100.,  False )
indk        = np.where((k<=0.5)&(k>=0.01))[0]
k           = k[indk]
Pden_Kaiser = Pden_Kaiser[indk,:]
Pmom_Kaiser = Pmom_Kaiser[indk,:]
Pcrs_Kaiser = Pcrs_Kaiser[indk,:]
# integral over \mu: 
Pden_Kaiser = sp.integrate.simps(Pden_Kaiser[:,mu>=0],mu[mu>=0],axis=1);
Pmom_Kaiser = sp.integrate.simps(Pmom_Kaiser[:,mu>=0],mu[mu>=0],axis=1);
Pcrs_Kaiser = sp.integrate.simps(Pcrs_Kaiser[:,mu>=0],mu[mu>=0],axis=1);


# 4: for comparison, we also calculate the nonlinear-model-PS by making the higher-order parameters to be 0: 
parm = [fsigma8, b1sigma8, 0, 0, 0,  b1sigma8, 0,0,0,0,0,0,0,0,0]
k,mu,Pden  = Pkmod_Fun(parm, Sig8_fid, PT, 'den', 1.,100.,1.,False) # I set [ a(z)=1, H(z)=100, D(z)=1 ] .
k,mu,Pmom  = Pkmod_Fun(parm, Sig8_fid, PT, 'mom', 1.,100.,1.,False)  
k,mu,Pcrs  = Pkmod_Fun(parm, Sig8_fid, PT, 'crs', 1.,100.,1.,False)  
indk       = np.where((k<=0.5)&(k>=0.01))[0]
k    = k[indk]
Pden = Pden[indk,:]
Pmom = Pmom[indk,:]
Pcrs = Pcrs[indk,:]
Pden_higher_order_parm0 = sp.integrate.simps(Pden[:,mu>=0],mu[mu>=0],axis=1);
Pmom_higher_order_parm0 = sp.integrate.simps(Pmom[:,mu>=0],mu[mu>=0],axis=1);
Pcrs_higher_order_parm0 = sp.integrate.simps(Pcrs[:,mu>=0],mu[mu>=0],axis=1);

# make some plots:
plt.figure(2,figsize=(20,5))
plt.subplot(131)
plt.plot(k, k*Pden_lin,c='r',label='make nonlinear mod to linear');
plt.plot(k, k*Pden_higher_order_parm0,c='gold',label='make nonlinear parms=0');
plt.scatter(k, k*Pden_Kaiser,c='green',label='Kaiser');plt.legend(fontsize=15)
plt.ylabel("$kP^{\delta}(k)$",fontsize=20);plt.xlabel("$k$ [h/Mpc]",fontsize=20);plt.tick_params( labelsize =15);
plt.xlim(0,0.25);plt.ylim(500,3750)
plt.subplot(132)
plt.plot(k, Pmom_lin,c='r',label='make nonlinear to linear');
plt.plot(k, Pmom_higher_order_parm0,c='gold',label='make nonlinear parms=0');
plt.scatter(k, Pmom_Kaiser,c='green',label='Kaiser');plt.yscale('log');plt.legend(fontsize=15)
plt.ylabel("$P^{p}(k)$",fontsize=20);plt.xlabel("$k$ [h/Mpc]",fontsize=20);plt.tick_params( labelsize =15);
plt.xlim(0,0.25);plt.ylim(10**6.5,10**12)
plt.subplot(133)
plt.plot(k, k*Pcrs_lin,c='r',label='make nonlinear mod to linear');
plt.plot(k, k*Pcrs_higher_order_parm0,c='gold',label='make nonlinear parms=0');
plt.scatter(k, k*Pcrs_Kaiser,c='green',label='Kaiser');plt.legend(fontsize=15)
plt.ylabel("$kP^{\delta p}(k)$",fontsize=20);plt.xlabel("$k$ [h/Mpc]",fontsize=20);plt.tick_params( labelsize =15);
plt.xlim(0,0.25);#plt.ylim(500,1750)
plt.show()

# %% [markdown]
# \
# <font color='brown'><font size="3.9">4.6.2 Comparing Power Spectrum Multipoles</font></font>

# %%
# comparing power spectrum multipoles: 
# set k-bins:
Nk           = 70
kbin         = np.linspace(0.01,0.38,Nk )

# linearlized perturbation model:
parm = [fsigma8, b1sigma8, 0, 0, 0,  b1sigma8, 0,0,0,0,0,0,0,0,0]
Pkmulti_den,kmulti_den, tmp,tmp           = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, np.nan,np.nan,np.nan, PTlin, 'den-024', 1.,100.,1., np.nan)
Pkmulti_mom,kmulti_mom, tmp,tmp           = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, np.nan,np.nan,np.nan, PTlin, 'mom-024', 1.,100.,1., np.nan)
Pkmulti_crs,kmulti_crs, tmp,tmp           = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, np.nan,np.nan,np.nan, PTlin, 'crs-13' , 1.,100.,1., np.nan) 
 
    
# Kaiser: In 'PkmodMulti_Fun', setting model_type='lin' gives you the Kaiser formula.
PSL=np.zeros((2,len(klin)))
PSL[0,:]=klin  ;  PSL[1,:]=Plin 
parm = [fsigma8, b1sigma8, 0, 0]
Pkmulti_den_kais,kmulti_den_kais, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, np.nan,np.nan,np.nan, PSL,   'den-024', 1.,100.,1., np.nan,'lin')
Pkmulti_mom_kais,kmulti_mom_kais, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, np.nan,np.nan,np.nan, PSL,   'mom-024', 1.,100.,1., np.nan,'lin')
Pkmulti_crs_kais,kmulti_crs_kais, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, np.nan,np.nan,np.nan, PSL,   'crs-13' , 1.,100.,1., np.nan,'lin') 
  

#make some plots:
plt.figure(4,figsize=(18,6))
plt.subplot(131)
plt.scatter(kmulti_den_kais[0*Nk:1*Nk]  ,kmulti_den_kais[0*Nk:1*Nk] * Pkmulti_den_kais[0*Nk:1*Nk]  ,c='r' ,label='kaiser $\ell=0$');
plt.scatter(kmulti_den_kais[1*Nk:2*Nk]  ,kmulti_den_kais[1*Nk:2*Nk] * Pkmulti_den_kais[1*Nk:2*Nk]  ,c='g' ,label='kaiser $\ell=2$');
plt.scatter(kmulti_den_kais[2*Nk:3*Nk]  ,kmulti_den_kais[2*Nk:3*Nk] * Pkmulti_den_kais[2*Nk:3*Nk]  ,c='b' ,label='kaiser $\ell=4$');
plt.plot(kmulti_den[0*Nk:1*Nk]  ,kmulti_den[0*Nk:1*Nk] * Pkmulti_den[0*Nk:1*Nk]    ,label='$\ell=0$');
plt.plot(kmulti_den[1*Nk:2*Nk]  ,kmulti_den[1*Nk:2*Nk] * Pkmulti_den[1*Nk:2*Nk]    ,label='$\ell=2$');
plt.plot(kmulti_den[2*Nk:3*Nk]  ,kmulti_den[2*Nk:3*Nk] * Pkmulti_den[2*Nk:3*Nk]    ,label='$\ell=4$');
plt.legend(fontsize=18); plt.xticks(fontsize=18); plt.yticks(fontsize=18); plt.xlim(0,0.4);plt.ylim(-500,3700);
plt.ylabel('$P^{\delta}_{\ell}(k)$',fontsize=23);plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.subplot(132)
plt.yscale('log')
plt.scatter(kmulti_mom_kais[0*Nk:1*Nk],Pkmulti_mom_kais[0*Nk:1*Nk]  ,c='r' );
plt.scatter(kmulti_mom_kais[1*Nk:2*Nk],Pkmulti_mom_kais[1*Nk:2*Nk]  ,c='g' );
plt.scatter(kmulti_mom_kais[2*Nk:3*Nk],Pkmulti_mom_kais[2*Nk:3*Nk]  ,c='b' );
plt.plot(kmulti_mom[0*Nk:1*Nk],Pkmulti_mom[0*Nk:1*Nk]   ,label='$\ell=0$');
plt.plot(kmulti_mom[1*Nk:2*Nk],Pkmulti_mom[1*Nk:2*Nk]   ,label='$\ell=2$');
plt.plot(kmulti_mom[2*Nk:3*Nk],Pkmulti_mom[2*Nk:3*Nk]   ,label='$\ell=4$');
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{\ell}(k)$',fontsize=23);plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23);plt.xlim(0,0.4)
plt.subplot(133)
plt.scatter(kmulti_crs_kais[0*Nk:1*Nk]  ,kmulti_crs_kais[0*Nk:1*Nk] * Pkmulti_crs_kais[0*Nk:1*Nk]  ,c='y'  );
plt.scatter(kmulti_crs_kais[1*Nk:2*Nk]  ,kmulti_crs_kais[1*Nk:2*Nk] * Pkmulti_crs_kais[1*Nk:2*Nk]  ,c='pink'  );
plt.plot(kmulti_crs[0*Nk:1*Nk]  ,kmulti_crs[0*Nk:1*Nk] * Pkmulti_crs[0*Nk:1*Nk]   ,label='$\ell=1$');
plt.plot(kmulti_crs[1*Nk:2*Nk]  ,kmulti_crs[1*Nk:2*Nk] * Pkmulti_crs[1*Nk:2*Nk]   ,label='$\ell=3$');
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta p}_{\ell}(k)$',fontsize=23);plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23);plt.xlim(0,0.4);plt.ylim(-0.2*10**6,3.*10**6)
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)

# %% [markdown]
# \
# <font color='brown'><font size="3.9">4.6.3 Window Function Convolution of Kaiser Formular</font></font>

# %%
fsigma8  = 0.437
b1sigma8 = 1.464
sigma_v  = 10.6    
sigmavv  = 1.6
parm = [fsigma8, b1sigma8, sigma_v, sigmavv]


# loading convolution matrix from files, they have been pre-computed: 
# Ross method:
covrossden, k_datar, k_modr, WF_rand = np.load(file_dir+'convden_Ross.npy',allow_pickle=True) 
covrossmom, k_datar, k_modr, WF_rand = np.load(file_dir+'convmom_Ross.npy',allow_pickle=True) 
# Blake method:
covden    , kdatab,  kmodb          = np.load(file_dir+'convden_CosmPS.npy',allow_pickle=True) 
covmom    , kdatab,  kmodb          = np.load(file_dir+'convmom_CosmPS.npy',allow_pickle=True) 
covcrs    , kdatab,  kmodb          = np.load(file_dir+'convcrs_CosmPS.npy',allow_pickle=True)
covCosmPS                           = [covden,covmom,covcrs]
Nkmod    = len(kmodb) 
Nkdat    = len(kdatab)
# Pypower: 
covden    , kdatap,  kmodp          = np.load(file_dir+'convden_Pypower.npy',allow_pickle=True) 
covmom    , kdatap,  kmodp          = np.load(file_dir+'convmom_Pypower.npy',allow_pickle=True) 
covcrs    , kdatap,  kmodp          = np.load(file_dir+'convcrs_Pypower.npy',allow_pickle=True)
covpypw                             = [covden,covmom,covcrs]
Nkdatp   = len(kdatap)
# build k-bins: 
k_datab  = np.concatenate(np.array([list(kdatab),list(kdatab),list(kdatab)]))
k_datap  = np.concatenate(np.array([list(kdatap),list(kdatap),list(kdatap)]))
k_modb   =                np.array([list(kmodb) ,list(kmodb) ,list(kmodb)])
k_modp   =                np.array([list(kmodp) ,list(kmodp) ,list(kmodp)])


# calculate the window function convolved power spectrum multipoles:
# density power: 
Pkmodc_denrg,kmodc_denrg,Pkmod_denrg,kmod_denrg = PkmodMulti_Fun(parm,True , Sig8_fid, k_datar , k_modr,  covrossden , WF_rand, PT, 'den-0'  , 1.,100.,1., 'Ross'    ,'lin')
Pkmodc_denb ,kmodc_denb ,Pkmod_denb ,kmod_denb  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datab , k_modb,  covCosmPS  , np.nan , PT, 'den-024', 1.,100.,1., 'CosmPS'   ,'lin')
Pkmodc_denp ,kmodc_denp ,Pkmod_denp ,kmod_denp  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datap , k_modp,  covpypw    , np.nan , PT, 'den-024', 1.,100.,1., 'Pypower' ,'lin')
# momentum power: 
Pkmodc_momrg,kmodc_momrg,Pkmod_momrg,kmod_momrg = PkmodMulti_Fun(parm,True , Sig8_fid, k_datar , k_modr,  covrossden , WF_rand, PT, 'mom-0'  , 1.,100.,1., 'Ross'    ,'lin')
Pkmodc_momb ,kmodc_momb ,Pkmod_momb ,kmod_momb  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datab , k_modb,  covCosmPS  , np.nan , PT, 'mom-024', 1.,100.,1., 'CosmPS'   ,'lin')
Pkmodc_momp ,kmodc_momp ,Pkmod_momp ,kmod_momp  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datap , k_modp,  covpypw    , np.nan , PT, 'mom-024', 1.,100.,1., 'Pypower' ,'lin')
# cross    power: 
Pkmodc_crsb ,kmodc_crsb ,Pkmod_crsb ,kmod_crsb  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datab , k_modb,  covCosmPS  , np.nan , PT, 'crs-13' , 1.,100.,1., 'CosmPS'   ,'lin')
Pkmodc_crsp ,kmodc_crsp ,Pkmod_crsp ,kmod_crsp  = PkmodMulti_Fun(parm,False, Sig8_fid, k_datap , k_modp,  covpypw    , np.nan , PT, 'crs-13' , 1.,100.,1., 'Pypower' ,'lin')          





# make plots:================================================================
plt.figure(5,figsize=(18,6))
plt.subplot(131)
plt.plot(kmod_denb[0*Nkmod:1*Nkmod]   , kmod_denb[0*Nkmod:1*Nkmod]   * Pkmod_denb[0*Nkmod:1*Nkmod]    ,c='silver',lw=4, label='Original Model PS')
plt.plot(kmodc_denrg                  , kmodc_denrg                  * Pkmodc_denrg                   ,c='lime',label='Conv PS Ross')
plt.plot(kmodc_denb[0*Nkdat:1*Nkdat]  , kmodc_denb[0*Nkdat:1*Nkdat]  * Pkmodc_denb[0*Nkdat:1*Nkdat]   ,c='orangered' ,  label='Conv PS CosmPS')
plt.plot(kmodc_denp[0*Nkdatp:1*Nkdatp], kmodc_denp[0*Nkdatp:1*Nkdatp]* Pkmodc_denp[0*Nkdatp:1*Nkdatp] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta}_{0}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43);#plt.ylim(0,1500)
plt.subplot(132)
plt.plot(kmod_denb[1*Nkmod:2*Nkmod]    ,kmod_denb[1*Nkmod:2*Nkmod]   * Pkmod_denb[1*Nkmod:2*Nkmod]    ,c='silver',lw=4, label='Original Model PS')
plt.plot(kmodc_denb[1*Nkdat:2*Nkdat]   ,kmodc_denb[1*Nkdat:2*Nkdat]  * Pkmodc_denb[1*Nkdat:2*Nkdat]   ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_denp[1*Nkdatp:2*Nkdatp] ,kmodc_denp[1*Nkdatp:2*Nkdatp]* Pkmodc_denp[1*Nkdatp:2*Nkdatp] ,c='deepskyblue',label='Conv PS pypower')
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.xlim(0,0.43);plt.ylim(-550,1300)
plt.ylabel('k $P^{\delta}_{2}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.subplot(133)
plt.plot(kmod_denb[2*Nkmod:3*Nkmod]    ,kmod_denb[2*Nkmod:3*Nkmod]   * Pkmod_denb[2*Nkmod:3*Nkmod]    ,c='silver',lw=4, label='Original Model PS')
plt.plot(kmodc_denb[2*Nkdat:3*Nkdat]   ,kmodc_denb[2*Nkdat:3*Nkdat]  * Pkmodc_denb[2*Nkdat:3*Nkdat]   ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_denp[2*Nkdatp:3*Nkdatp] ,kmodc_denp[2*Nkdatp:3*Nkdatp]* Pkmodc_denp[2*Nkdatp:3*Nkdatp] ,c='deepskyblue',label='Conv PS pypower')
plt.legend(fontsize=18);plt.xticks(fontsize=18);plt.yticks(fontsize=18)
plt.xlim(0,0.43);plt.ylim(-200,500)
plt.ylabel('k $P^{\delta}_{4}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)

plt.figure(6,figsize=(18,6))
plt.subplot(131)
plt.yscale('log')
plt.plot(kmod_momb[0*Nkmod:1*Nkmod]  , Pkmod_momb[0*Nkmod:1*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_momrg                 , Pkmodc_momrg                 ,c='lime',label='Conv PS Ross')
plt.plot(kmodc_momb[0*Nkdat:1*Nkdat] , Pkmodc_momb[0*Nkdat:1*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_momp[0*Nkdat:1*Nkdat] , Pkmodc_momp[0*Nkdat:1*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{0}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43)
plt.subplot(132)
plt.yscale('log')
plt.plot(kmod_momb[1*Nkmod:2*Nkmod]  , Pkmod_momb[1*Nkmod:2*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_momb[1*Nkdat:2*Nkdat] , Pkmodc_momb[1*Nkdat:2*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_momp[1*Nkdat:2*Nkdat] , Pkmodc_momp[1*Nkdat:2*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{2}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43); 
plt.subplot(133)
plt.yscale('log')
plt.plot(kmod_momb[2*Nkmod:3*Nkmod]  , Pkmod_momb[2*Nkmod:3*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_momb[2*Nkdat:3*Nkdat] , Pkmodc_momb[2*Nkdat:3*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_momp[2*Nkdat:3*Nkdat] , Pkmodc_momp[2*Nkdat:3*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('$P^{p}_{4}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43); 
plt.subplots_adjust(left=0.125,bottom=0.1, right=1.0, top=0.9, wspace=0.3, hspace=0.23)
 
plt.figure(7,figsize=(9,5))
plt.subplot(131)
plt.plot(kmod_crsb[0*Nkmod:1*Nkmod]  ,kmod_crsb[0*Nkmod:1*Nkmod] * Pkmod_crsb[0*Nkmod:1*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_crsb[0*Nkdat:1*Nkdat] ,kmodc_crsb[0*Nkdat:1*Nkdat]* Pkmodc_crsb[0*Nkdat:1*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_crsp[0*Nkdat:1*Nkdat] ,kmodc_crsp[0*Nkdat:1*Nkdat]* Pkmodc_crsp[0*Nkdat:1*Nkdat] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta p}_{1}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43);plt.ylim(-1.0*10**6,3*10**6)
plt.subplot(132)
plt.plot(kmod_crsb[1*Nkmod:2*Nkmod]    ,kmod_crsb[1*Nkmod:2*Nkmod]   * Pkmod_crsb[1*Nkmod:2*Nkmod]  ,c='silver',lw=4,label='Original Model PS')
plt.plot(kmodc_crsb[1*Nkdat:2*Nkdat]   ,kmodc_crsb[1*Nkdat:2*Nkdat]  * Pkmodc_crsb[1*Nkdat:2*Nkdat] ,c='orangered' ,label='Conv PS CosmPS')
plt.plot(kmodc_crsp[1*Nkdatp:2*Nkdatp] ,kmodc_crsp[1*Nkdatp:2*Nkdatp]* Pkmodc_crsp[1*Nkdatp:2*Nkdatp] ,c='dodgerblue',label='Conv PS pypower')
plt.legend(fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.ylabel('k $P^{\delta p}_{3}(k)$',fontsize=23)
plt.xlabel('k [h $Mpc^{-1}$]',fontsize=23)
plt.xlim(0,0.43);plt.ylim(-0.5*10**5,0.3*10**6)
plt.subplots_adjust(left=0.125,bottom=0.1, right=2.5, top=0.9, wspace=0.35, hspace=0.23)

# %% [markdown]
# \
# <font color='brown'><font size="4.9">Section 4.7 Calculate Fiducial Growth Rate at Effective Redshift</font></font>

# %%
Gamma_fid=0.55
fsig8_fid=Fsigma8_Fun(Gamma_fid,RsFeff,Sig8_fid, OmegaM, OmegaA )
print('Fidicial growth rate at z_eff=',RsFeff,'is fsigma8_fid=',fsig8_fid)
# Out:
# Fidicial growth rate at z_eff= 0.05 is fsigma8_fid= [0.44180121]

# %%
import os
os._exit(00)
# %reset -f

# %% [markdown]
# \
# \
# <font color='brown'><font size="5.9">Part 5. The Theoretical Models of the Galaxy Two-Point Correlation Function</font></font>
#
#
#
# This part is from Dr. Ryan Turner. rjturner@swin.edu.au
#
# The code used to convert the power spectrum to correlation function is buit up the python package 'hankl', see:\
#  https://hankl.readthedocs.io/en/latest/install.html \
# or\
#  https://github.com/minaskar/hankl.git \
#  Please cite the following paper:\
#  Karamanis et al. 2021: https://arxiv.org/abs/2106.06331
#
#
# The function is:\
# <font color='green'><font size="2">
# from PSmodFun import *  \
# r, CFs = CFmodMulti_Fun(r, k, Pmod , l,   kcut, PS_type)
# </font></font>
#
# where the keywords are:
#
# PS_type='den', 'mom' or 'crs' for auto-density, auto-momentum or cross- power spectrum, respectively.
#
# k: k-bins of the model power spectrum.
#
# Pmod :  power spectrum models.
#
# l :  the  power spectrum multipole order.
#
# kcut: maximum k value to use in power law extrapolation.
#
# \
# Firstly, we need to calculate the power spectrum models:

# %%
import numpy as np
import matplotlib.pyplot as plt
from PSmodFun import * # load the module of the model power spectrum  

# This is the directory to store your input and output data. This string should end with '/'.
file_dir =  "../Data/"   

# As mentioned before, we only need to calculate the loop term once, 
# therefore, in here, we directly load the loop terms from file.
sst          = np.load(file_dir+'INTEG_PL.npy',allow_pickle=True)
PT, Sig8_fid = sst  

# Here we just manually set these parameters, they are not fit results from any real surveys.
# growth rate:------------------
fsigma8        = 0.40946855 
# density field:---------------- 
b1sigma8       = 1.12568620 
b2sigma8       = 1.17890514 
bssigma8       = 'anal' 
b3nlsigma8     = 0.4335061 
sigmav1_squre  = 40.2873740 
sigmav2_squre  = 156.669623 
sigmav3_squre  = 1.8238754 
# momentum field:--------------- 
b1vsigma8      = 0.80151994 
b2vsigma8      = b2sigma8
bsvsigma8      = 'anal'
b3nlvsigma8    = 'anal'
sigmavv1_squre = 3.1344342 
sigmavv2_squre = 12.1289577
sigmavv3_squre = 1.27892345
#-------------------------------
# The list of parameters of power spectrum: 
parm = [fsigma8  ,  
        b1sigma8 , b2sigma8 , bssigma8 , b3nlsigma8   ,  
        b1vsigma8, b2vsigma8, bsvsigma8, b3nlvsigma8  ,   
        sigmav1_squre , sigmav2_squre  , sigmav3_squre,    
        sigmavv1_squre, sigmavv2_squre , sigmavv3_squre]

# set k-bins:
Nk           = 3000
kbin         = np.linspace(0.0001,0.42,Nk )

# the pre-factors of model-PS:
OmegaM  = 0.315192
OmegaA  = 1.- OmegaM
Hub     = 100.  
RsFeff = 0.20    
az     = 1./(1.+RsFeff)
Hz     = Hub * Ez(RsFeff, OmegaM, OmegaA, 0., -1., 0., 0.) # just use Hub = 100. 
Dz     = Dz_Fun(RsFeff, OmegaM, OmegaA)    

# calculate Power Spectrum Multipole Models:
# density ps:
Pkmulti_den,kmulti_den, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, 
                                                 np.nan,np.nan,np.nan, PT, 'den-024', az,Hz,Dz, np.nan)
# mom ps:
Pkmulti_mom,kmulti_mom, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, 
                                                 np.nan,np.nan,np.nan, PT, 'mom-024', az,Hz,Dz, np.nan)
# crs ps:
Pkmulti_crs,kmulti_crs, tmp,tmp = PkmodMulti_Fun(parm,False, Sig8_fid, kbin, 
                                                 np.nan,np.nan,np.nan, PT, 'crs-13' , az,Hz,Dz, np.nan)

# %% [markdown]
# \
# <font color='brown'><font size="4.9">5.1 Galaxy Correlation Function</font></font>

# %%
# k-bins of density power spectrum:
k     = kmulti_den[0*Nk:1*Nk]

# seperation-bins of correlation functions:
r     = np.logspace(np.log10(np.min(15)), np.log10(np.max(250)), 1000)

# density power spectrum multipoles:
Pden0 = Pkmulti_den[0*Nk:1*Nk]
Pden2 = Pkmulti_den[1*Nk:2*Nk]
Pden4 = Pkmulti_den[2*Nk:3*Nk]

# galaxy two-point correlation function multipoles:
r0,Xi0= CFmodMulti_Fun(r, k , Pden0, l=0, kcut=0.1,  PS_type='den') 
r2,Xi2= CFmodMulti_Fun(r, k , Pden2, l=2, kcut=0.1,  PS_type='den') 
r4,Xi4= CFmodMulti_Fun(r, k , Pden4, l=4, kcut=0.1,  PS_type='den') 
 
# make some plots:
plt.figure(1,figsize=(5,4))
plt.plot(r0, r0**2*Xi0, c='r' ,label='$\ell=0$');
plt.plot(r2, r2**2*Xi2, c='g' ,label='$\ell=2$');
#plt.plot(r4, r4**4*Xi4, c='b' ,label='$\ell=4$');
plt.legend(fontsize=18); plt.xticks(fontsize=18); plt.yticks(fontsize=18); 
plt.xlim(10,255);plt.ylim(-60,90);
plt.ylabel(r'$\xi^{\ell}_{gg}(r)$',fontsize=23);plt.xlabel('r [Mpc $h^{-1}$]',fontsize=23)
# Out:
# /Users/fei/anaconda3/lib/python3.11/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Text(0.5, 0, 'r [Mpc $h^{-1}$]')

# %% [markdown]
# <font color='brown'><font size="4.9">5.2 Velocity Correlation Function</font></font>

# %%
# momentum power spectrum l=0:
Pmom0 = Pkmulti_mom[0*Nk:1*Nk]

# velocity two-point correlation function multipoles:
r,psiperp, psipar= CFmodMulti_Fun(r, k , Pmom0, l=0, kcut=0.1, PS_type='mom') 

# make some plots:
plt.figure(2,figsize=(5,4))
plt.plot(r, psiperp, c='r' ,label='$\psi_{||}$');
plt.plot(r, psipar , c='g' ,label='$\psi_{\perp}$');
plt.legend(fontsize=18); plt.xticks(fontsize=18); plt.yticks(fontsize=18); 
plt.xlim(10,255); plt.ylim(-4500,59000);
plt.ylabel('$\psi(r)$',fontsize=23);plt.xlabel('r [Mpc $h^{-1}$]',fontsize=23)
# Out:
# Text(0.5, 0, 'r [Mpc $h^{-1}$]')

# %% [markdown]
# <font color='brown'><font size="4.9">5.3 Galaxy-Velocity Cross Correlation Function</font></font>

# %%
# momentum power spectrum l=0:
Pcrs1 = Pkmulti_crs[0*Nk:1*Nk]

# velocity two-point correlation function multipoles:
r,gv_dip= CFmodMulti_Fun(r, k , Pcrs1, l=1, kcut=0.1, PS_type='crs') 

# make some plots:
plt.figure(3,figsize=(4,3))
plt.plot(r, gv_dip , c='g' ); 
plt.xticks(fontsize=18); plt.yticks(fontsize=18); 
plt.xlim(10,255); plt.ylim( 0,100);
plt.ylabel(r'$\xi_{gv}(r)$',fontsize=23);plt.xlabel('r [Mpc $h^{-1}$]',fontsize=23)
# Out:
# Text(0.5, 0, 'r [Mpc $h^{-1}$]')

# %% [markdown]
# \
# \
# \
# <font color='brown'><font size="6">########. The End ! ########</font></font>
